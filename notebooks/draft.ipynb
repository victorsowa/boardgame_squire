# %% [markdown]
# # parsing

# %%
import requests
import xml.etree.ElementTree as ET

import pandas as pd

# %%
BASE_URI = 'https://www.boardgamegeek.com/xmlapi2/'

def get_users_collection(username):
    collections_endpoint = BASE_URI + 'collection?'
    parameters = f'username={username}&stats=1&own=1'
    return requests.get(collections_endpoint + parameters)

def get_xml_string_from_response(response):
    print(response.text)
    return ET.fromstring(response.text)

def get_game_ids_from_collection(collection_element_tree):
    return [child.attrib['objectid'] for child in collection_element_tree]


def get_user_ratings_from_collection(collection_element_tree):
    user_ratings_from_xml = [child.find('.//rating').get('value') for child in collection_element_tree]
    return [None if user_rating == 'N/A' else user_rating for user_rating in user_ratings_from_xml]


def get_games_from_game_ids(game_ids):
    comma_seperated_game_ids = ','.join(game_ids)
    thing_endpoint = BASE_URI + 'thing?'
    parameters = f'id={comma_seperated_game_ids}&stats=1'
    print(thing_endpoint + parameters)
    return requests.get(thing_endpoint + parameters)

# %%
class BoardgameXMLParser:
    def __init__(self, board_game_element):
        self.board_game_element = board_game_element
        self.type = self.board_game_element.get('type')
        self.id = self.board_game_element.get('id')
        self.title = self._get_attribute_from_element('name[@type="primary"]', 'value')
        self.description = self.board_game_element.find('description').text
        self.image = self.board_game_element.find('image').text
        self.thumbnail = self.board_game_element.find('thumbnail').text
        self.year_published = self._get_attribute_from_element('yearpublished', 'value')
        self.min_players_from_creators = self._get_attribute_from_element('minplayers', 'value')
        self.max_players_from_creators = self._get_attribute_from_element('maxplayers', 'value')
        self.playing_time = self._get_attribute_from_element('playingtime', 'value')
        self.min_playing_time = self._get_attribute_from_element('minplaytime', 'value')
        self.max_playing_time = self._get_attribute_from_element('maxplaytime', 'value')
        self.min_age = self._get_attribute_from_element('minage', 'value')
        self.average_rating = self._get_attribute_from_element('.//average', 'value')
        self.bayes_average_rating = self._get_attribute_from_element('.//bayesaverage', 'value')
        self.board_game_rank = self._get_attribute_from_element('.//rank[@name="boardgame"]', 'value')  
        
        self.designers = self._get_attributes_from_element('link[@type="boardgamedesigner"]', 'value')
        self.mechanics = self._get_attributes_from_element('link[@type="boardgamemechanic"]', 'value')
        self.categories = self._get_attributes_from_element('link[@type="boardgamecategory"]', 'value')
        
        suggested_player_poll_element, suggested_players_total_votes = self._get_poll_results('poll[@name="suggested_numplayers"]')

        if suggested_players_total_votes == 0:
            self.user_suggested_best_number_of_players = ''
            self.user_suggested_recommended_number_of_players = ''
        else:   
            suggested_player_counts_df = self._get_suggested_player_counts_dataframe(suggested_player_poll_element)
            suggested_player_counts_df_with_poll_result = self._get_suggested_player_counts_data_with_realtive_amounts(suggested_player_counts_df)
            self.user_suggested_best_number_of_players = self._get_best_player_counts(suggested_player_counts_df_with_poll_result)
            self.user_suggested_recommended_number_of_players = self._get_recommended_player_counts(suggested_player_counts_df_with_poll_result)
        
    def _get_attribute_from_element(self, find_string, attribute_name):
        element = self.board_game_element.find(f'{find_string}')
        return element.get(attribute_name)
    
    def _get_attributes_from_element(self, find_string, attribute_name):
        elements = self.board_game_element.findall(f'{find_string}')
        attributes = [element.get(attribute_name) for element in elements]
        return '|'.join(attributes)
    
    def _get_poll_results(self, poll_pattern):
        poll = self.board_game_element.find(poll_pattern)
        return (poll.findall('results'), int(poll.get('totalvotes')))
    
    def _get_suggested_player_counts_dataframe(self, suggested_player_poll_element):
        options = []
        for option in suggested_player_poll_element:
            option_row = {}
            option_row['num_players'] = option.get('numplayers')
            option_row['best'] = int(option.find('result[@value="Best"]').get('numvotes'))
            option_row['recommended'] = int(option.find('result[@value="Recommended"]').get('numvotes'))
            option_row['not_recommended'] = int(option.find('result[@value="Not Recommended"]').get('numvotes'))
            options.append(option_row)
        return pd.DataFrame(options)
    
    def _get_suggested_player_counts_data_with_realtive_amounts(self, suggested_player_counts_df):
        df = suggested_player_counts_df
        df.loc[df['not_recommended'] > df['recommended'] + df['best'], 'poll_result'] = 'not_recommended'
        df.loc[(df['poll_result'] != 'not_recommended') & (df['recommended'] < df['best']), 'poll_result'] = 'best'
        df.loc[(df['poll_result'] != 'not_recommended') & (df['poll_result'] != 'best'), 'poll_result'] = 'recommended'
        return df
        
    def _get_best_player_counts(self, poll_result):
        best_player_counts = poll_result.loc[poll_result['poll_result'] == 'best', 'num_players'].tolist()
        return '|'.join(best_player_counts)
    
    def _get_recommended_player_counts(self, poll_result):
        recommended_player_counts = poll_result.loc[poll_result['poll_result'] != 'not_recommended', 'num_players'].tolist()
        return '|'.join(recommended_player_counts)
    

class CollectionXMLParser():
    def __init__(self, bgg_username):
        pass
    def get_users_collection(username):
        BASE_URI = 'https://www.boardgamegeek.com/xmlapi2/'
        collections_endpoint = BASE_URI + 'collection?'
        parameters = f'username={username}'
        return request,s.get(collections_endpoint + parameters)

# %%
collection = get_users_collection('bobbaganush')

# %%
# Uses the api, own cell not to re-send the request

collection_et = get_xml_string_from_response(collection)

game_ids = get_game_ids_from_collection(collection_et)

user_games = list(zip(game_ids, get_user_ratings_from_collection(collection_et)))
user_games
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="yes"?><items totalitems="102" termsofuse="https://boardgamegeek.com/xmlapi/termsofuse" pubdate="Fri, 21 May 2021 16:30:53 +0000">
# 		<item objecttype="thing" objectid="68448" subtype="boardgame" collid="39629810">
# 	<name sortindex="1">7 Wonders</name>
# 		<yearpublished>2010</yearpublished>			https://cf.geekdo-images.com/RvFVTEpnbb4NM7k0IF8V7A__original/img/JQvRoz0xns9LZII74-ygKGDq_Es=/0x0/filters:format(jpeg)/pic860217.jpg
# 		<thumbnail>https://cf.geekdo-images.com/RvFVTEpnbb4NM7k0IF8V7A__thumb/img/ZlG_SRFChObHenw79fAve56_mnk=/fit-in/200x150/filters:strip_icc()/pic860217.jpg</thumbnail>
# 		<stats minplayers="2"																	maxplayers="7"																	minplaytime="30"																	maxplaytime="30"																	playingtime="30"																	numowned="114354" >
# 				<rating value="N/A">			<usersrated value="85822" />			<average value="7.74705" />
# 			<bayesaverage value="7.64611" />			<stddev value="1.27763" />
# 			<median value="0" />			<ranks>
# 												<rank type="subtype" id="1" name="boardgame" friendlyname="Board Game Rank" value="67" bayesaverage="7.64611" />
# 																<rank type="family" id="5497" name="strategygames" friendlyname="Strategy Game Rank" value="66" bayesaverage="7.61113" />
# 								<rank type="family" id="5499" name="familygames" friendlyname="Family Game Rank" value="9" bayesaverage="7.64292" />
# 											</ranks>		</rating>
# 			</stats>	<status own="1" prevowned="0" fortrade="0" want="0" wanttoplay="0" wanttobuy="0" wishlist="0"  preordered="0" lastmodified="2017-01-09 07:57:17" />
# 	<numplays>0</numplays>							</item>
# 		<item objecttype="thing" objectid="173346" subtype="boardgame" collid="42112237">
# 	<name sortindex="1">7 Wonders Duel</name>
# 		<yearpublished>2015</yearpublished>			https://cf.geekdo-images.com/WzNs1mA_o22ZWTR8fkLP2g__original/img/q_TrwF4VnXgW1dFQgtMJexSXOEA=/0x0/filters:format(jpeg)/pic3376065.jpg
# 		<thumbnail>https://cf.geekdo-images.com/WzNs1mA_o22ZWTR8fkLP2g__thumb/img/qGf8-LJx4lsNOgpjS6iCs2TyKts=/fit-in/200x150/filters:strip_icc()/pic3376065.jpg</thumbnail>
# 		<stats minplayers="2"																	maxplayers="2"																	minplaytime="30"																	maxplaytime="30"																	playingtime="30"																	numowned="98129" >
# 				<rating value="N/A">			<usersrated value="62660" />			<average value="8.10803" />
# 			<bayesaverage value="7.9816" />			<stddev value="1.18011" />
# 			<median value="0" />			<ranks>
# 												<rank type="subtype" id="1" name="boardgame" friendlyname="Board Game Rank" value="17" bayesaverage="7.9816" />
# 																<rank type="family" id="5497" name="strategygames" friendlyname="Strategy Game Rank" value="18" bayesaverage="7.95075" />
# 											</ranks>		</rating>
# 			</stats>	<status own="1" prevowned="0" fortrade="0" want="0" wanttoplay="0" wanttobuy="0" wishlist="0"  preordered="0" lastmodified="2017-04-25 06:28:45" />
# 	<numplays>0</numplays>							</item>
# 		<item objecttype="thing" objectid="31260" subtype="boardgame" collid="39629792">
# 	<name sortindex="1">Agricola</name>
# 		<yearpublished>2007</yearpublished>			https://cf.geekdo-images.com/dDDo2Hexl80ucK1IlqTk-g__original/img/toobKoejPiHpfpHk4SYd1UAJafw=/0x0/filters:format(jpeg)/pic831744.jpg
# 		<thumbnail>https://cf.geekdo-images.com/dDDo2Hexl80ucK1IlqTk-g__thumb/img/GHGdnCfeysoP_34gLnofJcNivW8=/fit-in/200x150/filters:strip_icc()/pic831744.jpg</thumbnail>
# 		<stats minplayers="1"																	maxplayers="5"																	minplaytime="30"																	maxplaytime="150"																	playingtime="150"																	numowned="76396" >
# 				<rating value="N/A">			<usersrated value="64166" />			<average value="7.94101" />
# 			<bayesaverage value="7.82635" />			<stddev value="1.55574" />
# 			<median value="0" />			<ranks>
# 												<rank type="subtype" id="1" name="boardgame" friendlyname="Board Game Rank" value="32" bayesaverage="7.82635" />
# 																<rank type="family" id="5497" name="strategygames" friendlyname="Strategy Game Rank" value="32" bayesaverage="7.81119" />
# 											</ranks>		</rating>
# 			</stats>	<status own="1" prevowned="0" fortrade="0" want="0" wanttoplay="0" wanttobuy="0" wishlist="0"  preordered="0" lastmodified="2017-01-09 07:56:41" />
# 	<numplays>4</numplays>							</item>
# 		<item objecttype="thing" objectid="13464" subtype="boardgame" collid="77843240">
# 	<name sortindex="1">Alfapet</name>
# 		<yearpublished>1994</yearpublished>			https://cf.geekdo-images.com/0xIeUho3Eme8PNAgR87nIg__original/img/kVVAUPVw4CqheyExmM9zaO_9934=/0x0/filters:format(jpeg)/pic3714347.jpg
# 		<thumbnail>https://cf.geekdo-images.com/0xIeUho3Eme8PNAgR87nIg__thumb/img/YkgjFAvySdVGmUghJXOWgoB0Shc=/fit-in/200x150/filters:strip_icc()/pic3714347.jpg</thumbnail>
# 		<stats minplayers="2"																	maxplayers="4"																	minplaytime="60"																	maxplaytime="60"																	playingtime="60"																	numowned="557" >
# 				<rating value="N/A">			<usersrated value="418" />			<average value="5.55347" />
# 			<bayesaverage value="5.50096" />			<stddev value="1.40683" />
# 			<median value="0" />			<ranks>
# 												<rank type="subtype" id="1" name="boardgame" friendlyname="Board Game Rank" value="16933" bayesaverage="5.50096" />
# 																<rank type="family" id="5499" name="familygames" friendlyname="Family Game Rank" value="2021" bayesaverage="5.48817" />
# 											</ranks>		</rating>
# 			</stats>	<status own="1" prevowned="0" fortrade="0" want="0" wanttoplay="0" wanttobuy="0" wishlist="0"  preordered="0" lastmodified="2021-01-01 12:22:53" />
# 	<numplays>1</numplays>							</item>
# 		<item objecttype="thing" objectid="205637" subtype="boardgame" collid="48497887">
# 	<name sortindex="1">Arkham Horror: The Card Game</name>
# 		<yearpublished>2016</yearpublished>			https://cf.geekdo-images.com/B5F5ulz0UivNgrI9Ky0euA__original/img/guEKCewM_2e5ugltSN3dTSwdZJI=/0x0/filters:format(jpeg)/pic3122349.jpg
# 		<thumbnail>https://cf.geekdo-images.com/B5F5ulz0UivNgrI9Ky0euA__thumb/img/L8ouPl5jv2Ye9MC4R_Os2zSGigE=/fit-in/200x150/filters:strip_icc()/pic3122349.jpg</thumbnail>
# 		<stats minplayers="1"																	maxplayers="2"																	minplaytime="60"																	maxplaytime="120"																	playingtime="120"																	numowned="52746" >
# 				<rating value="N/A">			<usersrated value="29654" />			<average value="8.1672" />
# 			<bayesaverage value="7.92311" />			<stddev value="1.49618" />
# 			<median value="0" />			<ranks>
# 												<rank type="subtype" id="1" name="boardgame" friendlyname="Board Game Rank" value="22" bayesaverage="7.92311" />
# 																<rank type="family" id="4667" name="cgs" friendlyname="Customizable Rank" value="1" bayesaverage="8.0153" />
# 								<rank type="family" id="5496" name="thematic" friendlyname="Thematic Rank" value="10" bayesaverage="7.94513" />
# 											</ranks>		</rating>
# 			</stats>	<status own="1" prevowned="0" fortrade="0" want="0" wanttoplay="0" wanttobuy="0" wishlist="0"  preordered="0" lastmodified="2018-01-04 03:21:07" />
# 	<numplays>0</numplays>							</item>
# 		<item objecttype="thing" objectid="230802" subtype="boardgame" collid="59903613">
# 	<name sortindex="1">Azul</name>
# 		<yearpublished>2017</yearpublished>			https://cf.geekdo-images.com/tz19PfklMdAdjxV9WArraA__original/img/eFRt3o7W6YltnrkqpiSOKr2rKCw=/0x0/filters:format(jpeg)/pic3718275.jpg
# 		<thumbnail>https://cf.geekdo-images.com/tz19PfklMdAdjxV9WArraA__thumb/img/debo694HgBaIBeNGyxu1ELUbQGA=/fit-in/200x150/filters:strip_icc()/pic3718275.jpg</thumbnail>
# 		<stats minplayers="2"																	maxplayers="4"																	minplaytime="30"																	maxplaytime="45"																	playingtime="45"																	numowned="83068" >
# 				<rating value="8">			<usersrated value="55918" />			<average value="7.82101" />
# 			<bayesaverage value="7.70427" />			<stddev value="1.14762" />
# 			<median value="0" />			<ranks>
# 												<rank type="subtype" id="1" name="boardgame" friendlyname="Board Game Rank" value="51" bayesaverage="7.70427" />
# 																<rank type="family" id="4666" name="abstracts" friendlyname="Abstract Game Rank" value="1" bayesaverage="7.67534" />
# 								<rank type="family" id="5499" name="familygames" friendlyname="Family Game Rank" value="4" bayesaverage="7.71655" />
# 											</ranks>		</rating>
# 			</stats>	<status own="1" prevowned="0" fortrade="0" want="0" wanttoplay="0" wanttobuy="0" wishlist="0"  preordered="0" lastmodified="2019-04-24 03:26:35" />
# 	<numplays>31</numplays>							</item>
# 		<item objecttype="thing" objectid="212445" subtype="boardgame" collid="82386218">
# 	<name sortindex="1">Blood Bowl (2016 Edition)</name>
# 		<yearpublished>2016</yearpublished>			https://cf.geekdo-images.com/1To3fG0-1ZpX1vfcHGHHYg__original/img/etLhChO09NvKGH9-c04Jw3Q92Xk=/0x0/filters:format(jpeg)/pic3254491.jpg
# 		<thumbnail>https://cf.geekdo-images.com/1To3fG0-1ZpX1vfcHGHHYg__thumb/img/CmBNLOWNnA-qMjMUZ-39OsNpD9w=/fit-in/200x150/filters:strip_icc()/pic3254491.jpg</thumbnail>
# 		<stats minplayers="2"																	maxplayers="2"																	minplaytime="45"																	maxplaytime="120"																	playingtime="120"																	numowned="4687" >
# 				<rating value="N/A">			<usersrated value="2272" />			<average value="8.06342" />
# 			<bayesaverage value="6.91641" />			<stddev value="1.51202" />
# 			<median value="0" />			<ranks>
# 												<rank type="subtype" id="1" name="boardgame" friendlyname="Board Game Rank" value="480" bayesaverage="6.91641" />
# 																<rank type="family" id="5496" name="thematic" friendlyname="Thematic Rank" value="71" bayesaverage="7.24696" />
# 											</ranks>		</rating>
# 			</stats>	<status own="1" prevowned="0" fortrade="0" want="0" wanttoplay="0" wanttobuy="0" wishlist="0"  preordered="0" lastmodified="2021-05-21 05:03:23" />
# 	<numplays>0</numplays>							</item>
# 		<item objecttype="thing" objectid="318472" subtype="boardgame" collid="82386220">
# 	<name sortindex="1">Blood Bowl: Second Season Edition</name>
# 		<yearpublished>2020</yearpublished>			https://cf.geekdo-images.com/EzU7wtB4o-DIlxHIQNL0kg__original/img/7RRMLnBGGZ0L2pDXTeUpowcW-UI=/0x0/filters:format(jpeg)/pic5688034.jpg
# 		<thumbnail>https://cf.geekdo-images.com/EzU7wtB4o-DIlxHIQNL0kg__thumb/img/0KZiyXGHvZGB6WnOzshrOekLP4I=/fit-in/200x150/filters:strip_icc()/pic5688034.jpg</thumbnail>
# 		<stats minplayers="2"																	maxplayers="2"																	minplaytime="45"																	maxplaytime="120"																	playingtime="120"																	numowned="740" >
# 				<rating value="N/A">			<usersrated value="215" />			<average value="8.75377" />
# 			<bayesaverage value="5.84351" />			<stddev value="1.41772" />
# 			<median value="0" />			<ranks>
# 												<rank type="subtype" id="1" name="boardgame" friendlyname="Board Game Rank" value="3354" bayesaverage="5.84351" />
# 											</ranks>		</rating>
# 			</stats>	<status own="1" prevowned="0" fortrade="0" want="0" wanttoplay="0" wanttobuy="0" wishlist="0"  preordered="0" lastmodified="2021-05-21 05:03:38" />
# 	<numplays>0</numplays>							</item>
# 		<item objecttype="thing" objectid="170216" subtype="boardgame" collid="39693141">
# 	<name sortindex="1">Blood Rage</name>
# 		<yearpublished>2015</yearpublished>			https://cf.geekdo-images.com/HkZSJfQnZ3EpS214xtuplg__original/img/Myy6IPDJDzLoPdXrPXVZcddBQoQ=/0x0/filters:format(jpeg)/pic2439223.jpg
# 		<thumbnail>https://cf.geekdo-images.com/HkZSJfQnZ3EpS214xtuplg__thumb/img/NLhVdU8xazrgS5dA6nVCYmN2DNI=/fit-in/200x150/filters:strip_icc()/pic2439223.jpg</thumbnail>
# 		<stats minplayers="2"																	maxplayers="4"																	minplaytime="60"																	maxplaytime="90"																	playingtime="90"																	numowned="41968" >
# 				<rating value="N/A">			<usersrated value="34862" />			<average value="7.99877" />
# 			<bayesaverage value="7.82153" />			<stddev value="1.40389" />
# 			<median value="0" />			<ranks>
# 												<rank type="subtype" id="1" name="boardgame" friendlyname="Board Game Rank" value="33" bayesaverage="7.82153" />
# 																<rank type="family" id="5497" name="strategygames" friendlyname="Strategy Game Rank" value="36" bayesaverage="7.8008" />
# 											</ranks>		</rating>
# 			</stats>	<status own="1" prevowned="0" fortrade="0" want="0" wanttoplay="0" wanttobuy="0" wishlist="0"  preordered="0" lastmodified="2017-01-11 09:06:27" />
# 	<numplays>3</numplays>							</item>
# 		<item objecttype="thing" objectid="174506" subtype="boardgame" collid="49778896">
# 	<name sortindex="1">Blood Rage: 5th Player Expansion</name>
# 		<yearpublished>2015</yearpublished>			https://cf.geekdo-images.com/umhSABukjE3U7oDSBr4JMA__original/img/4Xo2d8o3W1dpD_P9aaqSCWYpA6w=/0x0/filters:format(jpeg)/pic6063944.jpg
# 		<thumbnail>https://cf.geekdo-images.com/umhSABukjE3U7oDSBr4JMA__thumb/img/ILs4K1hMfMGgb8_BTX_ngR9j7Is=/fit-in/200x150/filters:strip_icc()/pic6063944.jpg</thumbnail>
# 		<stats minplayers="5"																	maxplayers="5"																	minplaytime="60"																	maxplaytime="90"																	playingtime="90"																	numowned="9994" >
# 				<rating value="N/A">			<usersrated value="2345" />			<average value="8.0998" />
# 			<bayesaverage value="6.9963" />			<stddev value="1.28498" />
# 			<median value="0" />			<ranks>
# 												<rank type="subtype" id="1" name="boardgame" friendlyname="Board Game Rank" value="Not Ranked" bayesaverage="6.9963" />
# 											</ranks>		</rating>
# 			</stats>	<status own="1" prevowned="0" fortrade="0" want="0" wanttoplay="0" wanttobuy="0" wishlist="0"  preordered="0" lastmodified="2018-02-20 09:28:12" />
# 	<numplays>0</numplays>							</item>
# 		<item objecttype="thing" objectid="174801" subtype="boardgame" collid="56346201">
# 	<name sortindex="1">Blood Rage: Gods of Ásgard</name>
# 		<yearpublished>2015</yearpublished>			https://cf.geekdo-images.com/GljxjWlqsAPaWnu4Sb3s4A__original/img/CYJNOIzCtkbJESo7tRwnPtSEr1s=/0x0/filters:format(jpeg)/pic3320476.jpg
# 		<thumbnail>https://cf.geekdo-images.com/GljxjWlqsAPaWnu4Sb3s4A__thumb/img/imR4BxctZ0vAxRBw8Gj1KULTjN0=/fit-in/200x150/filters:strip_icc()/pic3320476.jpg</thumbnail>
# 		<stats minplayers="2"																	maxplayers="4"																	minplaytime="60"																	maxplaytime="90"																	playingtime="90"																	numowned="9824" >
# 				<rating value="N/A">			<usersrated value="2133" />			<average value="7.68547" />
# 			<bayesaverage value="6.70592" />			<stddev value="1.28592" />
# 			<median value="0" />			<ranks>
# 												<rank type="subtype" id="1" name="boardgame" friendlyname="Board Game Rank" value="Not Ranked" bayesaverage="6.70592" />
# 											</ranks>		</rating>
# 			</stats>	<status own="1" prevowned="0" fortrade="0" want="0" wanttoplay="0" wanttobuy="0" wishlist="0"  preordered="0" lastmodified="2018-12-04 00:27:25" />
# 	<numplays>0</numplays>							</item>
# 		<item objecttype="thing" objectid="224517" subtype="boardgame" collid="77843245">
# 	<name sortindex="1">Brass: Birmingham</name>
# 		<yearpublished>2018</yearpublished>			https://cf.geekdo-images.com/x3zxjr-Vw5iU4yDPg70Jgw__original/img/FpyxH41Y6_ROoePAilPNEhXnzO8=/0x0/filters:format(jpeg)/pic3490053.jpg
# 		<thumbnail>https://cf.geekdo-images.com/x3zxjr-Vw5iU4yDPg70Jgw__thumb/img/o18rjEemoWaVru9Y2TyPwuIaRfE=/fit-in/200x150/filters:strip_icc()/pic3490053.jpg</thumbnail>
# 		<stats minplayers="2"																	maxplayers="4"																	minplaytime="60"																	maxplaytime="120"																	playingtime="120"																	numowned="31401" >
# 				<rating value="N/A">			<usersrated value="20830" />			<average value="8.67221" />
# 			<bayesaverage value="8.39676" />			<stddev value="1.24767" />
# 			<median value="0" />			<ranks>
# 												<rank type="subtype" id="1" name="boardgame" friendlyname="Board Game Rank" value="3" bayesaverage="8.39676" />
# 																<rank type="family" id="5497" name="strategygames" friendlyname="Strategy Game Rank" value="3" bayesaverage="8.44183" />
# 											</ranks>		</rating>
# 			</stats>	<status own="1" prevowned="0" fortrade="0" want="0" wanttoplay="0" wanttobuy="0" wishlist="0"  preordered="0" lastmodified="2021-01-01 12:22:55" />
# 	<numplays>0</numplays>							</item>
# 		<item objecttype="thing" objectid="171131" subtype="boardgame" collid="50323072">
# 	<name sortindex="1">Captain Sonar</name>
# 		<yearpublished>2016</yearpublished>			https://cf.geekdo-images.com/eVy9IyAVtzzKv2VvPHFPbA__original/img/vSfK0lGYI45DIcyrOkTPYzI412M=/0x0/filters:format(png)/pic3013621.png
# 		<thumbnail>https://cf.geekdo-images.com/eVy9IyAVtzzKv2VvPHFPbA__thumb/img/RavsPCF6el7VEaVR1OG5M2ZGCrk=/fit-in/200x150/filters:strip_icc()/pic3013621.png</thumbnail>
# 		<stats minplayers="2"																	maxplayers="8"																	minplaytime="45"																	maxplaytime="60"																	playingtime="60"																	numowned="22354" >
# 				<rating value="N/A">			<usersrated value="16307" />			<average value="7.56292" />
# 			<bayesaverage value="7.34833" />			<stddev value="1.3746" />
# 			<median value="0" />			<ranks>
# 												<rank type="subtype" id="1" name="boardgame" friendlyname="Board Game Rank" value="168" bayesaverage="7.34833" />
# 																<rank type="family" id="5496" name="thematic" friendlyname="Thematic Rank" value="48" bayesaverage="7.36098" />
# 								<rank type="family" id="5498" name="partygames" friendlyname="Party Game Rank" value="6" bayesaverage="7.40217" />
# 											</ranks>		</rating>
# 			</stats>	<status own="1" prevowned="0" fortrade="0" want="0" wanttoplay="0" wanttobuy="0" wishlist="0"  preordered="0" lastmodified="2018-03-15 10:54:20" />
# 	<numplays>0</numplays>							</item>
# 		<item objecttype="thing" objectid="822" subtype="boardgame" collid="39629751">
# 	<name sortindex="1">Carcassonne</name>
# 		<yearpublished>2000</yearpublished>			https://cf.geekdo-images.com/Z3upN53-fsVPUDimN9SpOA__original/img/9LEvU4EbbBrJB36YgWQXeXQYwjo=/0x0/filters:format(jpeg)/pic2337577.jpg
# 		<thumbnail>https://cf.geekdo-images.com/Z3upN53-fsVPUDimN9SpOA__thumb/img/_C5pWATlaq3uS8u7IlFb0WMi_ak=/fit-in/200x150/filters:strip_icc()/pic2337577.jpg</thumbnail>
# 		<stats minplayers="2"																	maxplayers="5"																	minplaytime="30"																	maxplaytime="45"																	playingtime="45"																	numowned="152332" >
# 				<rating value="N/A">			<usersrated value="103716" />			<average value="7.41951" />
# 			<bayesaverage value="7.30975" />			<stddev value="1.30463" />
# 			<median value="0" />			<ranks>
# 												<rank type="subtype" id="1" name="boardgame" friendlyname="Board Game Rank" value="183" bayesaverage="7.30975" />
# 																<rank type="family" id="5499" name="familygames" friendlyname="Family Game Rank" value="35" bayesaverage="7.30342" />
# 											</ranks>		</rating>
# 			</stats>	<status own="1" prevowned="0" fortrade="0" want="0" wanttoplay="0" wanttobuy="0" wishlist="0"  preordered="0" lastmodified="2017-01-09 07:55:30" />
# 	<numplays>0</numplays>							</item>
# 		<item objecttype="thing" objectid="21385" subtype="boardgame" collid="39629759">
# 	<name sortindex="1">Carcassonne: Expansion 4 – The Tower</name>
# 		<yearpublished>2006</yearpublished>			https://cf.geekdo-images.com/P42FlP0SXP4mU6jGVpxLiA__original/img/OHLjk7e3VtM1hVcpx4A6Cs4tp_s=/0x0/filters:format(jpeg)/pic3763555.jpg
# 		<thumbnail>https://cf.geekdo-images.com/P42FlP0SXP4mU6jGVpxLiA__thumb/img/dmVXydki-L7XIqagwRLFUbl6Pn0=/fit-in/200x150/filters:strip_icc()/pic3763555.jpg</thumbnail>
# 		<stats minplayers="2"																	maxplayers="6"																	minplaytime="60"																	maxplaytime="60"																	playingtime="60"																	numowned="15212" >
# 				<rating value="N/A">			<usersrated value="5408" />			<average value="6.57398" />
# 			<bayesaverage value="6.278" />			<stddev value="1.45146" />
# 			<median value="0" />			<ranks>
# 												<rank type="subtype" id="1" name="boardgame" friendlyname="Board Game Rank" value="Not Ranked" bayesaverage="6.278" />
# 																<rank type="family" id="5497" name="strategygames" friendlyname="Strategy Game Rank" value="Not Ranked" bayesaverage="6.29798" />
# 								<rank type="family" id="5499" name="familygames" friendlyname="Family Game Rank" value="Not Ranked" bayesaverage="6.33705" />
# 											</ranks>		</rating>
# 			</stats>	<status own="1" prevowned="0" fortrade="0" want="0" wanttoplay="0" wanttobuy="0" wishlist="0"  preordered="0" lastmodified="2017-01-09 07:55:48" />
# 	<numplays>0</numplays>							</item>
# 		<item objecttype="thing" objectid="13" subtype="boardgame" collid="39629742">
# 	<name sortindex="1">Catan</name>
# 		<yearpublished>1995</yearpublished>			https://cf.geekdo-images.com/W3Bsga_uLP9kO91gZ7H8yw__original/img/xV7oisd3RQ8R-k18cdWAYthHXsA=/0x0/filters:format(jpeg)/pic2419375.jpg
# 		<thumbnail>https://cf.geekdo-images.com/W3Bsga_uLP9kO91gZ7H8yw__thumb/img/8a9HeqFydO7Uun_le9bXWPnidcA=/fit-in/200x150/filters:strip_icc()/pic2419375.jpg</thumbnail>
# 		<stats minplayers="3"																	maxplayers="4"																	minplaytime="60"																	maxplaytime="120"																	playingtime="120"																	numowned="157621" >
# 				<rating value="N/A">			<usersrated value="103182" />			<average value="7.14912" />
# 			<bayesaverage value="6.98478" />			<stddev value="1.48088" />
# 			<median value="0" />			<ranks>
# 												<rank type="subtype" id="1" name="boardgame" friendlyname="Board Game Rank" value="403" bayesaverage="6.98478" />
# 																<rank type="family" id="5497" name="strategygames" friendlyname="Strategy Game Rank" value="381" bayesaverage="6.8599" />
# 								<rank type="family" id="5499" name="familygames" friendlyname="Family Game Rank" value="116" bayesaverage="6.93017" />
# 											</ranks>		</rating>
# 			</stats>	<status own="1" prevowned="0" fortrade="0" want="0" wanttoplay="0" wanttobuy="0" wishlist="0"  preordered="0" lastmodified="2017-01-09 07:55:03" />
# 	<numplays>0</numplays>							</item>
# 		<item objecttype="thing" objectid="926" subtype="boardgame" collid="39457986">
# 	<name sortindex="1">Catan: Cities &amp; Knights</name>
# 		<yearpublished>1998</yearpublished>			https://cf.geekdo-images.com/XVjc87_UzjIhagFeO4r8ew__original/img/EjqC0K9hK6XJOEkF6Hmaz3MKndI=/0x0/filters:format(jpeg)/pic2420315.jpg
# 		<thumbnail>https://cf.geekdo-images.com/XVjc87_UzjIhagFeO4r8ew__thumb/img/MVJhRxVHfoSpVOSSYwvzyn8hTCw=/fit-in/200x150/filters:strip_icc()/pic2420315.jpg</thumbnail>
# 		<stats minplayers="3"																	maxplayers="4"																	minplaytime="90"																	maxplaytime="90"																	playingtime="90"																	numowned="34746" >
# 				<rating value="N/A">			<usersrated value="17366" />			<average value="7.45542" />
# 			<bayesaverage value="7.19279" />			<stddev value="1.4627" />
# 			<median value="0" />			<ranks>
# 												<rank type="subtype" id="1" name="boardgame" friendlyname="Board Game Rank" value="Not Ranked" bayesaverage="7.19279" />
# 																<rank type="family" id="5497" name="strategygames" friendlyname="Strategy Game Rank" value="Not Ranked" bayesaverage="7.16774" />
# 											</ranks>		</rating>
# 			</stats>	<status own="1" prevowned="0" fortrade="0" want="0" wanttoplay="0" wanttobuy="0" wishlist="0"  preordered="0" lastmodified="2017-01-03 09:50:43" />
# 	<numplays>0</numplays>							</item>
# 		<item objecttype="thing" objectid="325" subtype="boardgame" collid="39629747">
# 	<name sortindex="1">Catan: Seafarers</name>
# 		<yearpublished>1997</yearpublished>			https://cf.geekdo-images.com/yO6X6iObEb7PtECKCagMKg__original/img/-qVRY-CT5a9OgOHRg5qMaVaeOQg=/0x0/filters:format(jpeg)/pic2420293.jpg
# 		<thumbnail>https://cf.geekdo-images.com/yO6X6iObEb7PtECKCagMKg__thumb/img/sADKPjQ9M3aZgwONMdYvPgmme6c=/fit-in/200x150/filters:strip_icc()/pic2420293.jpg</thumbnail>
# 		<stats minplayers="3"																	maxplayers="4"																	minplaytime="90"																	maxplaytime="90"																	playingtime="90"																	numowned="35851" >
# 				<rating value="N/A">			<usersrated value="16609" />			<average value="7.15156" />
# 			<bayesaverage value="6.93244" />			<stddev value="1.33908" />
# 			<median value="0" />			<ranks>
# 												<rank type="subtype" id="1" name="boardgame" friendlyname="Board Game Rank" value="Not Ranked" bayesaverage="6.93244" />
# 																<rank type="family" id="5497" name="strategygames" friendlyname="Strategy Game Rank" value="Not Ranked" bayesaverage="6.90532" />
# 								<rank type="family" id="5499" name="familygames" friendlyname="Family Game Rank" value="Not Ranked" bayesaverage="6.95026" />
# 											</ranks>		</rating>
# 			</stats>	<status own="1" prevowned="0" fortrade="0" want="0" wanttoplay="0" wanttobuy="0" wishlist="0"  preordered="0" lastmodified="2017-01-09 07:55:17" />
# 	<numplays>0</numplays>							</item>
# 		<item objecttype="thing" objectid="553" subtype="boardgame" collid="39629842">
# 	<name sortindex="1">Chez Geek</name>
# 		<yearpublished>1999</yearpublished>			https://cf.geekdo-images.com/N7gjVapkyDt0SyMcF_0zqA__original/img/pg5ZKLrJOLFDmt2IhGYrqAvaiLM=/0x0/filters:format(jpeg)/pic918250.jpg
# 		<thumbnail>https://cf.geekdo-images.com/N7gjVapkyDt0SyMcF_0zqA__thumb/img/Y8phCwpdGeNNgUOP5Lkl493FKxI=/fit-in/200x150/filters:strip_icc()/pic918250.jpg</thumbnail>
# 		<stats minplayers="2"																	maxplayers="5"																	minplaytime="60"																	maxplaytime="60"																	playingtime="60"																	numowned="7544" >
# 				<rating value="N/A">			<usersrated value="4399" />			<average value="5.72072" />
# 			<bayesaverage value="5.59218" />			<stddev value="1.615" />
# 			<median value="0" />			<ranks>
# 												<rank type="subtype" id="1" name="boardgame" friendlyname="Board Game Rank" value="7508" bayesaverage="5.59218" />
# 																<rank type="family" id="5496" name="thematic" friendlyname="Thematic Rank" value="1015" bayesaverage="5.55647" />
# 								<rank type="family" id="5498" name="partygames" friendlyname="Party Game Rank" value="531" bayesaverage="5.43601" />
# 											</ranks>		</rating>
# 			</stats>	<status own="1" prevowned="0" fortrade="0" want="0" wanttoplay="0" wanttobuy="0" wishlist="0"  preordered="0" lastmodified="2017-01-09 07:58:19" />
# 	<numplays>0</numplays>							</item>
# 		<item objecttype="thing" objectid="478" subtype="boardgame" collid="39629823">
# 	<name sortindex="1">Citadels</name>
# 		<yearpublished>2000</yearpublished>			https://cf.geekdo-images.com/42iW4E-vOumFXRQAiSf-GA__original/img/ochY5pK4sq4vtzkka0OPRwsGLOE=/0x0/filters:format(jpeg)/pic3239104.jpg
# 		<thumbnail>https://cf.geekdo-images.com/42iW4E-vOumFXRQAiSf-GA__thumb/img/lxwVwqIO1RkDyyykSDFnpmwbgyI=/fit-in/200x150/filters:strip_icc()/pic3239104.jpg</thumbnail>
# 		<stats minplayers="2"																	maxplayers="8"																	minplaytime="20"																	maxplaytime="60"																	playingtime="60"																	numowned="65061" >
# 				<rating value="N/A">			<usersrated value="48815" />			<average value="7.08066" />
# 			<bayesaverage value="6.97409" />			<stddev value="1.26187" />
# 			<median value="0" />			<ranks>
# 												<rank type="subtype" id="1" name="boardgame" friendlyname="Board Game Rank" value="412" bayesaverage="6.97409" />
# 																<rank type="family" id="5497" name="strategygames" friendlyname="Strategy Game Rank" value="327" bayesaverage="6.92826" />
# 								<rank type="family" id="5499" name="familygames" friendlyname="Family Game Rank" value="104" bayesaverage="6.95153" />
# 											</ranks>		</rating>
# 			</stats>	<status own="1" prevowned="0" fortrade="0" want="0" wanttoplay="0" wanttobuy="0" wishlist="0"  preordered="0" lastmodified="2017-01-09 07:57:46" />
# 	<numplays>0</numplays>							</item>
# 		<item objecttype="thing" objectid="178900" subtype="boardgame" collid="44444406">
# 	<name sortindex="1">Codenames</name>
# 		<yearpublished>2015</yearpublished>			https://cf.geekdo-images.com/F_KDEu0GjdClml8N7c8Imw__original/img/gcX_EfjsRpB5fI4Ug4XV73G4jGI=/0x0/filters:format(jpeg)/pic2582929.jpg
# 		<thumbnail>https://cf.geekdo-images.com/F_KDEu0GjdClml8N7c8Imw__thumb/img/yl8iXxSNwguMeg3KkmfFO9SMVVc=/fit-in/200x150/filters:strip_icc()/pic2582929.jpg</thumbnail>
# 		<stats minplayers="2"																	maxplayers="8"																	minplaytime="15"																	maxplaytime="15"																	playingtime="15"																	numowned="110517" >
# 				<rating value="N/A">			<usersrated value="69326" />			<average value="7.61263" />
# 			<bayesaverage value="7.52374" />			<stddev value="1.29914" />
# 			<median value="0" />			<ranks>
# 												<rank type="subtype" id="1" name="boardgame" friendlyname="Board Game Rank" value="96" bayesaverage="7.52374" />
# 																<rank type="family" id="5498" name="partygames" friendlyname="Party Game Rank" value="2" bayesaverage="7.54893" />
# 											</ranks>		</rating>
# 			</stats>	<status own="1" prevowned="0" fortrade="0" want="0" wanttoplay="0" wanttobuy="0" wishlist="0"  preordered="0" lastmodified="2017-08-11 02:06:09" />
# 	<numplays>6</numplays>							</item>
# 		<item objecttype="thing" objectid="198773" subtype="boardgame" collid="77843230">
# 	<name sortindex="1">Codenames: Pictures</name>
# 		<yearpublished>2016</yearpublished>			https://cf.geekdo-images.com/Q2u-Nk68Wb1iLjxh_dfsIg__original/img/i4FVjrk9TtmvVlVK7NtwRqgOxdQ=/0x0/filters:format(jpeg)/pic3476592.jpg
# 		<thumbnail>https://cf.geekdo-images.com/Q2u-Nk68Wb1iLjxh_dfsIg__thumb/img/6-1EOESE196KVKw4xOJ5rge56j0=/fit-in/200x150/filters:strip_icc()/pic3476592.jpg</thumbnail>
# 		<stats minplayers="2"																	maxplayers="8"																	minplaytime="15"																	maxplaytime="15"																	playingtime="15"																	numowned="30150" >
# 				<rating value="N/A">			<usersrated value="17421" />			<average value="7.25568" />
# 			<bayesaverage value="7.07981" />			<stddev value="1.2587" />
# 			<median value="0" />			<ranks>
# 												<rank type="subtype" id="1" name="boardgame" friendlyname="Board Game Rank" value="324" bayesaverage="7.07981" />
# 																<rank type="family" id="5498" name="partygames" friendlyname="Party Game Rank" value="18" bayesaverage="7.13801" />
# 											</ranks>		</rating>
# 			</stats>	<status own="1" prevowned="0" fortrade="0" want="0" wanttoplay="0" wanttobuy="0" wishlist="0"  preordered="0" lastmodified="2021-01-01 12:22:48" />
# 	<numplays>0</numplays>							</item>
# 		<item objecttype="thing" objectid="39463" subtype="boardgame" collid="46717174">
# 	<name sortindex="1">Cosmic Encounter</name>
# 		<yearpublished>2008</yearpublished>			https://cf.geekdo-images.com/S8cE-Ld7XP5sVz-upKJ-Bg__original/img/c4ZrfOtpp6tDHLyMsKecc2ne370=/0x0/filters:format(jpeg)/pic1521633.jpg
# 		<thumbnail>https://cf.geekdo-images.com/S8cE-Ld7XP5sVz-upKJ-Bg__thumb/img/gE--xqnuor4bft2J361zxJJGCjM=/fit-in/200x150/filters:strip_icc()/pic1521633.jpg</thumbnail>
# 		<stats minplayers="3"																	maxplayers="5"																	minplaytime="60"																	maxplaytime="120"																	playingtime="120"																	numowned="34307" >
# 				<rating value="N/A">			<usersrated value="27718" />			<average value="7.53852" />
# 			<bayesaverage value="7.3715" />			<stddev value="1.70372" />
# 			<median value="0" />			<ranks>
# 												<rank type="subtype" id="1" name="boardgame" friendlyname="Board Game Rank" value="151" bayesaverage="7.3715" />
# 																<rank type="family" id="5496" name="thematic" friendlyname="Thematic Rank" value="60" bayesaverage="7.30804" />
# 								<rank type="family" id="5497" name="strategygames" friendlyname="Strategy Game Rank" value="136" bayesaverage="7.33269" />
# 											</ranks>		</rating>
# 			</stats>	<status own="1" prevowned="0" fortrade="0" want="0" wanttoplay="0" wanttobuy="0" wishlist="0"  preordered="0" lastmodified="2017-11-08 09:48:45" />
# 	<numplays>0</numplays>							</item>
# 		<item objecttype="thing" objectid="225694" subtype="boardgame" collid="77843254">
# 	<name sortindex="1">Decrypto</name>
# 		<yearpublished>2018</yearpublished>			https://cf.geekdo-images.com/hHZWXnUTMYDd_KTAM6Jwlw__original/img/lL6QJ69UmZT7CeljUcjyA47b-e0=/0x0/filters:format(jpeg)/pic3759421.jpg
# 		<thumbnail>https://cf.geekdo-images.com/hHZWXnUTMYDd_KTAM6Jwlw__thumb/img/O5XHaPOALYquS058qcXWVm5b_k4=/fit-in/200x150/filters:strip_icc()/pic3759421.jpg</thumbnail>
# 		<stats minplayers="3"																	maxplayers="8"																	minplaytime="15"																	maxplaytime="45"																	playingtime="45"																	numowned="20021" >
# 				<rating value="N/A">			<usersrated value="12345" />			<average value="7.79614" />
# 			<bayesaverage value="7.49905" />			<stddev value="1.24352" />
# 			<median value="0" />			<ranks>
# 												<rank type="subtype" id="1" name="boardgame" friendlyname="Board Game Rank" value="104" bayesaverage="7.49905" />
# 																<rank type="family" id="5498" name="partygames" friendlyname="Party Game Rank" value="1" bayesaverage="7.62538" />
# 											</ranks>		</rating>
# 			</stats>	<status own="1" prevowned="0" fortrade="0" want="0" wanttoplay="0" wanttobuy="0" wishlist="0"  preordered="0" lastmodified="2021-01-01 12:22:59" />
# 	<numplays>0</numplays>							</item>
# 		<item objecttype="thing" objectid="104162" subtype="boardgame" collid="56905710">
# 	<name sortindex="1">Descent: Journeys in the Dark (Second Edition)</name>
# 		<yearpublished>2012</yearpublished>			https://cf.geekdo-images.com/ZN2rpiJ19lg5DZk_iYMMkQ__original/img/E7OjZXGfe2Vfj2qis30aXetbQJQ=/0x0/filters:format(jpeg)/pic1180640.jpg
# 		<thumbnail>https://cf.geekdo-images.com/ZN2rpiJ19lg5DZk_iYMMkQ__thumb/img/C6XETjkjDq3zebWc7-Rf_WKh2ak=/fit-in/200x150/filters:strip_icc()/pic1180640.jpg</thumbnail>
# 		<stats minplayers="1"																	maxplayers="5"																	minplaytime="120"																	maxplaytime="120"																	playingtime="120"																	numowned="36069" >
# 				<rating value="6">			<usersrated value="22947" />			<average value="7.68459" />
# 			<bayesaverage value="7.43746" />			<stddev value="1.46981" />
# 			<median value="0" />			<ranks>
# 												<rank type="subtype" id="1" name="boardgame" friendlyname="Board Game Rank" value="122" bayesaverage="7.43746" />
# 																<rank type="family" id="5496" name="thematic" friendlyname="Thematic Rank" value="38" bayesaverage="7.44519" />
# 											</ranks>		</rating>
# 			</stats>	<status own="1" prevowned="0" fortrade="0" want="0" wanttoplay="0" wanttobuy="0" wishlist="0"  preordered="0" lastmodified="2019-12-17 04:32:42" />
# 	<numplays>1</numplays>			<comment>I can see how this game could be fun with another gaming group. Not exactly a bad experience but not a terrific one either.</comment>				</item>
# 		<item objecttype="thing" objectid="36218" subtype="boardgame" collid="39630006">
# 	<name sortindex="1">Dominion</name>
# 		<yearpublished>2008</yearpublished>			https://cf.geekdo-images.com/j6iQpZ4XkemZP07HNCODBA__original/img/96COuakNiLRrjDLc1sM4Zxsw4WE=/0x0/filters:format(jpeg)/pic394356.jpg
# 		<thumbnail>https://cf.geekdo-images.com/j6iQpZ4XkemZP07HNCODBA__thumb/img/B2u2ghwlmI_qsUtCwuvcbnBcIqU=/fit-in/200x150/filters:strip_icc()/pic394356.jpg</thumbnail>
# 		<stats minplayers="2"																	maxplayers="4"																	minplaytime="30"																	maxplaytime="30"																	playingtime="30"																	numowned="103095" >
# 				<rating value="N/A">			<usersrated value="79027" />			<average value="7.6167" />
# 			<bayesaverage value="7.50736" />			<stddev value="1.42442" />
# 			<median value="0" />			<ranks>
# 												<rank type="subtype" id="1" name="boardgame" friendlyname="Board Game Rank" value="100" bayesaverage="7.50736" />
# 																<rank type="family" id="5497" name="strategygames" friendlyname="Strategy Game Rank" value="98" bayesaverage="7.46419" />
# 											</ranks>		</rating>
# 			</stats>	<status own="1" prevowned="0" fortrade="0" want="0" wanttoplay="0" wanttobuy="0" wishlist="0"  preordered="0" lastmodified="2017-01-09 08:03:49" />
# 	<numplays>0</numplays>							</item>
# 		<item objecttype="thing" objectid="5177" subtype="boardgame" collid="39629934">
# 	<name sortindex="1">Drakborgen Legenden</name>
# 		<yearpublished>2002</yearpublished>			https://cf.geekdo-images.com/86fL3oI36nS5OIwS1qlLMg__original/img/omw4vZTn2gIXdwbUdmSXPfTKXNI=/0x0/filters:format(jpeg)/pic17832.jpg
# 		<thumbnail>https://cf.geekdo-images.com/86fL3oI36nS5OIwS1qlLMg__thumb/img/TidK-DU0ADqpvA09sNEKsRu-uTY=/fit-in/200x150/filters:strip_icc()/pic17832.jpg</thumbnail>
# 		<stats minplayers="2"																	maxplayers="4"																	minplaytime="90"																	maxplaytime="90"																	playingtime="90"																	numowned="371" >
# 				<rating value="N/A">			<usersrated value="259" />			<average value="5.93745" />
# 			<bayesaverage value="5.54018" />			<stddev value="1.51788" />
# 			<median value="0" />			<ranks>
# 												<rank type="subtype" id="1" name="boardgame" friendlyname="Board Game Rank" value="11056" bayesaverage="5.54018" />
# 																<rank type="family" id="5496" name="thematic" friendlyname="Thematic Rank" value="1001" bayesaverage="5.56806" />
# 											</ranks>		</rating>
# 			</stats>	<status own="1" prevowned="0" fortrade="0" want="0" wanttoplay="0" wanttobuy="0" wishlist="0"  preordered="0" lastmodified="2017-01-09 08:01:31" />
# 	<numplays>0</numplays>							</item>
# 		<item objecttype="thing" objectid="283355" subtype="boardgame" collid="67526381">
# 	<name sortindex="1">Dune</name>
# 		<yearpublished>2019</yearpublished>			https://cf.geekdo-images.com/2fgPg6Be--w97zoycObUgg__original/img/7PyNxWs85_OKGOm_jYVFvPwAViE=/0x0/filters:format(jpeg)/pic4815198.jpg
# 		<thumbnail>https://cf.geekdo-images.com/2fgPg6Be--w97zoycObUgg__thumb/img/OrjzwJVfE8Qnk8e5efbae5EaSeY=/fit-in/200x150/filters:strip_icc()/pic4815198.jpg</thumbnail>
# 		<stats minplayers="2"																	maxplayers="6"																	minplaytime="120"																	maxplaytime="120"																	playingtime="120"																	numowned="9903" >
# 				<rating value="N/A">			<usersrated value="3499" />			<average value="8.13784" />
# 			<bayesaverage value="7.16638" />			<stddev value="1.60326" />
# 			<median value="0" />			<ranks>
# 												<rank type="subtype" id="1" name="boardgame" friendlyname="Board Game Rank" value="262" bayesaverage="7.16638" />
# 																<rank type="family" id="5496" name="thematic" friendlyname="Thematic Rank" value="42" bayesaverage="7.39575" />
# 								<rank type="family" id="5497" name="strategygames" friendlyname="Strategy Game Rank" value="155" bayesaverage="7.29027" />
# 											</ranks>		</rating>
# 			</stats>	<status own="1" prevowned="0" fortrade="0" want="0" wanttoplay="0" wanttobuy="0" wishlist="0"  preordered="0" lastmodified="2020-01-07 06:02:18" />
# 	<numplays>0</numplays>							</item>
# 		<item objecttype="thing" objectid="157958" subtype="boardgame" collid="77843242">
# 	<name sortindex="1">DungeonQuest Revised Edition</name>
# 		<yearpublished>2014</yearpublished>			https://cf.geekdo-images.com/fp_QRuZe9hfPY_k7Ff3jIQ__original/img/SJdA5IPcgMtVSOt5XiZOYhgNTNE=/0x0/filters:format(jpeg)/pic2017396.jpg
# 		<thumbnail>https://cf.geekdo-images.com/fp_QRuZe9hfPY_k7Ff3jIQ__thumb/img/-Y35xyBseYa1e4z0iK-gumwbgys=/fit-in/200x150/filters:strip_icc()/pic2017396.jpg</thumbnail>
# 		<stats minplayers="1"																	maxplayers="4"																	minplaytime="60"																	maxplaytime="60"																	playingtime="60"																	numowned="2437" >
# 				<rating value="N/A">			<usersrated value="1360" />			<average value="7.07791" />
# 			<bayesaverage value="6.16708" />			<stddev value="1.57948" />
# 			<median value="0" />			<ranks>
# 												<rank type="subtype" id="1" name="boardgame" friendlyname="Board Game Rank" value="1824" bayesaverage="6.16708" />
# 																<rank type="family" id="5496" name="thematic" friendlyname="Thematic Rank" value="352" bayesaverage="6.3869" />
# 											</ranks>		</rating>
# 			</stats>	<status own="1" prevowned="0" fortrade="0" want="0" wanttoplay="0" wanttobuy="0" wishlist="0"  preordered="0" lastmodified="2021-01-01 12:22:54" />
# 	<numplays>2</numplays>							</item>
# 		<item objecttype="thing" objectid="72125" subtype="boardgame" collid="77843248">
# 	<name sortindex="1">Eclipse</name>
# 		<yearpublished>2011</yearpublished>			https://cf.geekdo-images.com/cnFppsVNOSTJ-W3APQFuTg__original/img/AbcjscBi-x3tVrsJsBhXq2RxLbc=/0x0/filters:format(jpeg)/pic1974056.jpg
# 		<thumbnail>https://cf.geekdo-images.com/cnFppsVNOSTJ-W3APQFuTg__thumb/img/X8XQO2_mRl7HRSzzOEgoKrWulj4=/fit-in/200x150/filters:strip_icc()/pic1974056.jpg</thumbnail>
# 		<stats minplayers="2"																	maxplayers="6"																	minplaytime="60"																	maxplaytime="180"																	playingtime="180"																	numowned="26833" >
# 				<rating value="N/A">			<usersrated value="26348" />			<average value="7.8872" />
# 			<bayesaverage value="7.69931" />			<stddev value="1.49618" />
# 			<median value="0" />			<ranks>
# 												<rank type="subtype" id="1" name="boardgame" friendlyname="Board Game Rank" value="52" bayesaverage="7.69931" />
# 																<rank type="family" id="5497" name="strategygames" friendlyname="Strategy Game Rank" value="49" bayesaverage="7.70633" />
# 											</ranks>		</rating>
# 			</stats>	<status own="1" prevowned="0" fortrade="0" want="0" wanttoplay="0" wanttobuy="0" wishlist="0"  preordered="0" lastmodified="2021-01-01 12:22:57" />
# 	<numplays>1</numplays>							</item>
# 		<item objecttype="thing" objectid="246900" subtype="boardgame" collid="73746955">
# 	<name sortindex="1">Eclipse: Second Dawn for the Galaxy</name>
# 		<yearpublished>2020</yearpublished>			https://cf.geekdo-images.com/Oh3kHw6lweg6ru71Q16h2Q__original/img/yW7d4RNfU1ndISCaPlfGYUyxnRU=/0x0/filters:format(jpeg)/pic5235277.jpg
# 		<thumbnail>https://cf.geekdo-images.com/Oh3kHw6lweg6ru71Q16h2Q__thumb/img/e9XZdQe1ZcPpaq4Gy31OoWBB_V0=/fit-in/200x150/filters:strip_icc()/pic5235277.jpg</thumbnail>
# 		<stats minplayers="2"																	maxplayers="6"																	minplaytime="60"																	maxplaytime="200"																	playingtime="200"																	numowned="6188" >
# 				<rating value="9">			<usersrated value="3315" />			<average value="8.78681" />
# 			<bayesaverage value="7.5691" />			<stddev value="1.33628" />
# 			<median value="0" />			<ranks>
# 												<rank type="subtype" id="1" name="boardgame" friendlyname="Board Game Rank" value="83" bayesaverage="7.5691" />
# 																<rank type="family" id="5497" name="strategygames" friendlyname="Strategy Game Rank" value="39" bayesaverage="7.77821" />
# 											</ranks>		</rating>
# 			</stats>	<status own="1" prevowned="0" fortrade="0" want="0" wanttoplay="0" wanttobuy="0" wishlist="0"  preordered="0" lastmodified="2020-08-19 23:41:54" />
# 	<numplays>0</numplays>			<comment>It is very much the same game as the first edition. The easier put up and teardown is a huge improvment though!</comment>				</item>
# 		<item objecttype="thing" objectid="175621" subtype="boardgame" collid="51837818">
# 	<name sortindex="1">Epic Card Game</name>
# 		<yearpublished>2015</yearpublished>			https://cf.geekdo-images.com/DfhQjeh-IzvUMFH__QUDXA__original/img/o7b9oFEfBQ4BOtY_bOhDQ6C4Jlw=/0x0/filters:format(jpeg)/pic2691347.jpg
# 		<thumbnail>https://cf.geekdo-images.com/DfhQjeh-IzvUMFH__QUDXA__thumb/img/TrfK1csWE7BMdCMmG8TQWLb5fAE=/fit-in/200x150/filters:strip_icc()/pic2691347.jpg</thumbnail>
# 		<stats minplayers="2"																	maxplayers="4"																	minplaytime="20"																	maxplaytime="40"																	playingtime="40"																	numowned="10409" >
# 				<rating value="N/A">			<usersrated value="4352" />			<average value="6.4618" />
# 			<bayesaverage value="6.12551" />			<stddev value="1.69276" />
# 			<median value="0" />			<ranks>
# 												<rank type="subtype" id="1" name="boardgame" friendlyname="Board Game Rank" value="1963" bayesaverage="6.12551" />
# 																<rank type="family" id="4667" name="cgs" friendlyname="Customizable Rank" value="84" bayesaverage="6.32066" />
# 											</ranks>		</rating>
# 			</stats>	<status own="1" prevowned="0" fortrade="0" want="0" wanttoplay="0" wanttobuy="0" wishlist="0"  preordered="0" lastmodified="2018-05-23 09:09:25" />
# 	<numplays>0</numplays>							</item>
# 		<item objecttype="thing" objectid="177736" subtype="boardgame" collid="52150694">
# 	<name sortindex="3">A Feast for Odin</name>
# 		<yearpublished>2016</yearpublished>			https://cf.geekdo-images.com/s9oGMCo1fcfV4Dk3EnqLZw__original/img/N1X-0JB1GapFVhl98nP4tNFXMcM=/0x0/filters:format(png)/pic3146943.png
# 		<thumbnail>https://cf.geekdo-images.com/s9oGMCo1fcfV4Dk3EnqLZw__thumb/img/AKxMMz2DTbBrEynhDROla8fdjJ4=/fit-in/200x150/filters:strip_icc()/pic3146943.png</thumbnail>
# 		<stats minplayers="1"																	maxplayers="4"																	minplaytime="30"																	maxplaytime="120"																	playingtime="120"																	numowned="23734" >
# 				<rating value="N/A">			<usersrated value="18016" />			<average value="8.1976" />
# 			<bayesaverage value="7.9362" />			<stddev value="1.3574" />
# 			<median value="0" />			<ranks>
# 												<rank type="subtype" id="1" name="boardgame" friendlyname="Board Game Rank" value="21" bayesaverage="7.9362" />
# 																<rank type="family" id="5497" name="strategygames" friendlyname="Strategy Game Rank" value="17" bayesaverage="7.98007" />
# 											</ranks>		</rating>
# 			</stats>	<status own="1" prevowned="0" fortrade="0" want="0" wanttoplay="0" wanttobuy="0" wishlist="0"  preordered="0" lastmodified="2018-06-07 06:14:29" />
# 	<numplays>0</numplays>							</item>
# 		<item objecttype="thing" objectid="199478" subtype="boardgame" collid="47940253">
# 	<name sortindex="1">Flamme Rouge</name>
# 		<yearpublished>2016</yearpublished>			https://cf.geekdo-images.com/sUrK5CCscls-tTc2hJWDPg__original/img/hQOFypZgCn4CQrJnXiNaQc_hjCw=/0x0/filters:format(jpeg)/pic3482521.jpg
# 		<thumbnail>https://cf.geekdo-images.com/sUrK5CCscls-tTc2hJWDPg__thumb/img/tBSMuRSHRl4M8-dVxcThAC1yXbs=/fit-in/200x150/filters:strip_icc()/pic3482521.jpg</thumbnail>
# 		<stats minplayers="2"																	maxplayers="4"																	minplaytime="30"																	maxplaytime="45"																	playingtime="45"																	numowned="16440" >
# 				<rating value="N/A">			<usersrated value="12596" />			<average value="7.5521" />
# 			<bayesaverage value="7.27332" />			<stddev value="1.27052" />
# 			<median value="0" />			<ranks>
# 												<rank type="subtype" id="1" name="boardgame" friendlyname="Board Game Rank" value="201" bayesaverage="7.27332" />
# 																<rank type="family" id="5499" name="familygames" friendlyname="Family Game Rank" value="31" bayesaverage="7.31802" />
# 											</ranks>		</rating>
# 			</stats>	<status own="1" prevowned="0" fortrade="0" want="0" wanttoplay="0" wanttobuy="0" wishlist="0"  preordered="0" lastmodified="2017-12-26 08:24:00" />
# 	<numplays>1</numplays>							</item>
# 		<item objecttype="thing" objectid="169124" subtype="boardgame" collid="44444410">
# 	<name sortindex="1">Flick &#039;em Up!</name>
# 		<yearpublished>2015</yearpublished>			https://cf.geekdo-images.com/uTrqB91Kzvqtb4Ophk1BPw__original/img/8A3BjcqOLKDl_f3yuT6Gfb392js=/0x0/filters:format(jpeg)/pic5095159.jpg
# 		<thumbnail>https://cf.geekdo-images.com/uTrqB91Kzvqtb4Ophk1BPw__thumb/img/uYpJnYTjRgevqAtujITGFBdHNU4=/fit-in/200x150/filters:strip_icc()/pic5095159.jpg</thumbnail>
# 		<stats minplayers="2"																	maxplayers="10"																	minplaytime="30"																	maxplaytime="45"																	playingtime="45"																	numowned="14504" >
# 				<rating value="N/A">			<usersrated value="7845" />			<average value="6.93914" />
# 			<bayesaverage value="6.67582" />			<stddev value="1.25073" />
# 			<median value="0" />			<ranks>
# 												<rank type="subtype" id="1" name="boardgame" friendlyname="Board Game Rank" value="769" bayesaverage="6.67582" />
# 																<rank type="family" id="5496" name="thematic" friendlyname="Thematic Rank" value="201" bayesaverage="6.75703" />
# ...
# 	<name sortindex="1">Tiny Epic Kingdoms</name>
# 		<yearpublished>2014</yearpublished>			https://cf.geekdo-images.com/rEBwFqk9b4rT-hrGOQnZrA__original/img/N-czadI8K2PdDuvOw7Vy50R7qls=/0x0/filters:format(jpeg)/pic2947892.jpg
# 		<thumbnail>https://cf.geekdo-images.com/rEBwFqk9b4rT-hrGOQnZrA__thumb/img/nIQB6TR1SMbF1W1Oq4OlhIbnao4=/fit-in/200x150/filters:strip_icc()/pic2947892.jpg</thumbnail>
# 		<stats minplayers="2"																	maxplayers="5"																	minplaytime="30"																	maxplaytime="45"																	playingtime="45"																	numowned="17138" >
# 				<rating value="N/A">			<usersrated value="7111" />			<average value="6.59141" />
# 			<bayesaverage value="6.35465" />			<stddev value="1.27799" />
# 			<median value="0" />			<ranks>
# 												<rank type="subtype" id="1" name="boardgame" friendlyname="Board Game Rank" value="1312" bayesaverage="6.35465" />
# 																<rank type="family" id="5497" name="strategygames" friendlyname="Strategy Game Rank" value="815" bayesaverage="6.37033" />
# 											</ranks>		</rating>
# 			</stats>	<status own="1" prevowned="0" fortrade="0" want="0" wanttoplay="0" wanttobuy="0" wishlist="0"  preordered="0" lastmodified="2020-09-04 02:00:34" />
# 	<numplays>0</numplays>							</item>
# 		<item objecttype="thing" objectid="233078" subtype="boardgame" collid="47260049">
# 	<name sortindex="1">Twilight Imperium: Fourth Edition</name>
# 		<yearpublished>2017</yearpublished>			https://cf.geekdo-images.com/_Ppn5lssO5OaildSE-FgFA__original/img/kVpZ0Maa_LeQGWxOqsYKP3N4KUY=/0x0/filters:format(jpeg)/pic3727516.jpg
# 		<thumbnail>https://cf.geekdo-images.com/_Ppn5lssO5OaildSE-FgFA__thumb/img/lfEukJE0JsoZZObaF9K9YnFp62E=/fit-in/200x150/filters:strip_icc()/pic3727516.jpg</thumbnail>
# 		<stats minplayers="3"																	maxplayers="6"																	minplaytime="240"																	maxplaytime="480"																	playingtime="480"																	numowned="17662" >
# 				<rating value="9">			<usersrated value="14086" />			<average value="8.6936" />
# 			<bayesaverage value="8.2554" />			<stddev value="1.59246" />
# 			<median value="0" />			<ranks>
# 												<rank type="subtype" id="1" name="boardgame" friendlyname="Board Game Rank" value="5" bayesaverage="8.2554" />
# 																<rank type="family" id="5496" name="thematic" friendlyname="Thematic Rank" value="4" bayesaverage="8.31879" />
# 								<rank type="family" id="5497" name="strategygames" friendlyname="Strategy Game Rank" value="4" bayesaverage="8.29616" />
# 											</ranks>		</rating>
# 			</stats>	<status own="1" prevowned="0" fortrade="0" want="0" wanttoplay="0" wanttobuy="0" wishlist="0"  preordered="0" lastmodified="2019-12-17 04:41:01" />
# 	<numplays>1</numplays>			<comment>A game with 6 players takes way longer than the box suggests. Our longest was about 18 hours (our shortest around 12). But a game is always an event and I have not yet had a player at the table who regretted joining.
#
# Very important that everyone has read/watched the rules before joining their first time. It is an absolute pain to teach and takes important time from actually playing the game, which is long enough already.</comment>				</item>
# 		<item objecttype="thing" objectid="126163" subtype="boardgame" collid="77843238">
# 	<name sortindex="1">Tzolk&#039;in: The Mayan Calendar</name>
# 		<yearpublished>2012</yearpublished>			https://cf.geekdo-images.com/kXf7mDyDYuHg6oe8yTUIEA__original/img/f6-Au0KTnNR4nugSu2U-wPNbZCU=/0x0/filters:format(jpeg)/pic4604439.jpg
# 		<thumbnail>https://cf.geekdo-images.com/kXf7mDyDYuHg6oe8yTUIEA__thumb/img/or9mAn4ClljY_wO_zvsLJDqs9tU=/fit-in/200x150/filters:strip_icc()/pic4604439.jpg</thumbnail>
# 		<stats minplayers="2"																	maxplayers="4"																	minplaytime="90"																	maxplaytime="90"																	playingtime="90"																	numowned="36359" >
# 				<rating value="N/A">			<usersrated value="31472" />			<average value="7.90157" />
# 			<bayesaverage value="7.7525" />			<stddev value="1.267" />
# 			<median value="0" />			<ranks>
# 												<rank type="subtype" id="1" name="boardgame" friendlyname="Board Game Rank" value="41" bayesaverage="7.7525" />
# 																<rank type="family" id="5497" name="strategygames" friendlyname="Strategy Game Rank" value="41" bayesaverage="7.77147" />
# 											</ranks>		</rating>
# 			</stats>	<status own="1" prevowned="0" fortrade="0" want="0" wanttoplay="0" wanttobuy="0" wishlist="0"  preordered="0" lastmodified="2021-01-01 12:22:52" />
# 	<numplays>0</numplays>							</item>
# 		<item objecttype="thing" objectid="122328" subtype="boardgame" collid="50407512">
# 	<name sortindex="1">War of the Ring: Lords of Middle-earth</name>
# 		<yearpublished>2012</yearpublished>			https://cf.geekdo-images.com/zt2LzaUrs-jETOzumDuXjw__original/img/Ub3Iu3UZvyDen8l13VggO2TMKuU=/0x0/filters:format(jpeg)/pic1450880.jpg
# 		<thumbnail>https://cf.geekdo-images.com/zt2LzaUrs-jETOzumDuXjw__thumb/img/W4nkpElzS8C9bTGJHIW2L6I_CSU=/fit-in/200x150/filters:strip_icc()/pic1450880.jpg</thumbnail>
# 		<stats minplayers="2"																	maxplayers="4"																	minplaytime="180"																	maxplaytime="180"																	playingtime="180"																	numowned="7651" >
# 				<rating value="N/A">			<usersrated value="1505" />			<average value="8.60837" />
# 			<bayesaverage value="6.91184" />			<stddev value="1.22074" />
# 			<median value="0" />			<ranks>
# 												<rank type="subtype" id="1" name="boardgame" friendlyname="Board Game Rank" value="Not Ranked" bayesaverage="6.91184" />
# 																<rank type="family" id="4664" name="wargames" friendlyname="War Game Rank" value="Not Ranked" bayesaverage="7.75835" />
# 								<rank type="family" id="5496" name="thematic" friendlyname="Thematic Rank" value="Not Ranked" bayesaverage="7.38031" />
# 											</ranks>		</rating>
# 			</stats>	<status own="1" prevowned="0" fortrade="0" want="0" wanttoplay="0" wanttobuy="0" wishlist="0"  preordered="0" lastmodified="2018-03-19 08:10:43" />
# 	<numplays>0</numplays>							</item>
# 		<item objecttype="thing" objectid="115746" subtype="boardgame" collid="50323077">
# 	<name sortindex="1">War of the Ring: Second Edition</name>
# 		<yearpublished>2012</yearpublished>			https://cf.geekdo-images.com/ImPgGag98W6gpV1KV812aA__original/img/38jB7fN07DwlrGKYAf-J0vsNdgs=/0x0/filters:format(jpeg)/pic1215633.jpg
# 		<thumbnail>https://cf.geekdo-images.com/ImPgGag98W6gpV1KV812aA__thumb/img/X-lBBdG4uO6LT0y1vXxCN4jdR4M=/fit-in/200x150/filters:strip_icc()/pic1215633.jpg</thumbnail>
# 		<stats minplayers="2"																	maxplayers="4"																	minplaytime="150"																	maxplaytime="180"																	playingtime="180"																	numowned="23146" >
# 				<rating value="N/A">			<usersrated value="14205" />			<average value="8.49523" />
# 			<bayesaverage value="8.11307" />			<stddev value="1.48853" />
# 			<median value="0" />			<ranks>
# 												<rank type="subtype" id="1" name="boardgame" friendlyname="Board Game Rank" value="13" bayesaverage="8.11307" />
# 																<rank type="family" id="4664" name="wargames" friendlyname="War Game Rank" value="2" bayesaverage="8.2162" />
# 								<rank type="family" id="5496" name="thematic" friendlyname="Thematic Rank" value="6" bayesaverage="8.18818" />
# 											</ranks>		</rating>
# 			</stats>	<status own="1" prevowned="0" fortrade="0" want="0" wanttoplay="0" wanttobuy="0" wishlist="0"  preordered="0" lastmodified="2018-03-15 10:54:29" />
# 	<numplays>2</numplays>							</item>
# 		<item objecttype="thing" objectid="228051" subtype="boardgame" collid="72879139">
# 	<name sortindex="1">Warhammer 40,000: Heroes of Black Reach</name>
# 		<yearpublished>2018</yearpublished>			https://cf.geekdo-images.com/AIBQ4QN0iWr_7ZsQshbspA__original/img/ARpVr8lcx-uUbU0mNAwgV5du0Z0=/0x0/filters:format(png)/pic4223812.png
# 		<thumbnail>https://cf.geekdo-images.com/AIBQ4QN0iWr_7ZsQshbspA__thumb/img/HtvM00IFmNpogZgcVzoxmLWRFHs=/fit-in/200x150/filters:strip_icc()/pic4223812.png</thumbnail>
# 		<stats minplayers="2"																	maxplayers="2"																	minplaytime="30"																	maxplaytime="120"																	playingtime="120"																	numowned="1106" >
# 				<rating value="N/A">			<usersrated value="292" />			<average value="8.17055" />
# 			<bayesaverage value="5.79411" />			<stddev value="1.61573" />
# 			<median value="0" />			<ranks>
# 												<rank type="subtype" id="1" name="boardgame" friendlyname="Board Game Rank" value="3765" bayesaverage="5.79411" />
# 																<rank type="family" id="4664" name="wargames" friendlyname="War Game Rank" value="462" bayesaverage="6.47901" />
# 											</ranks>		</rating>
# 			</stats>	<status own="1" prevowned="0" fortrade="0" want="0" wanttoplay="0" wanttobuy="0" wishlist="0"  preordered="0" lastmodified="2020-07-21 02:28:53" />
# 	<numplays>0</numplays>							</item>
# 		<item objecttype="thing" objectid="261594" subtype="boardgame" collid="55557591">
# 	<name sortindex="1">Warhammer Underworlds: Nightvault</name>
# 		<yearpublished>2018</yearpublished>			https://cf.geekdo-images.com/viScuLBeqS4GcnSc545R1w__original/img/DOnO8OUI3MSqTo_URKsAuR3Sj-8=/0x0/filters:format(jpeg)/pic4327788.jpg
# 		<thumbnail>https://cf.geekdo-images.com/viScuLBeqS4GcnSc545R1w__thumb/img/vI6cXMSLzM0BgA5FJZcsZdQEnbM=/fit-in/200x150/filters:strip_icc()/pic4327788.jpg</thumbnail>
# 		<stats minplayers="2"																	maxplayers="2"																	minplaytime="30"																	maxplaytime="60"																	playingtime="60"																	numowned="2356" >
# 				<rating value="N/A">			<usersrated value="824" />			<average value="7.92715" />
# 			<bayesaverage value="6.26891" />			<stddev value="1.35617" />
# 			<median value="0" />			<ranks>
# 												<rank type="subtype" id="1" name="boardgame" friendlyname="Board Game Rank" value="1517" bayesaverage="6.26891" />
# 											</ranks>		</rating>
# 			</stats>	<status own="1" prevowned="0" fortrade="0" want="0" wanttoplay="0" wanttobuy="0" wishlist="0"  preordered="0" lastmodified="2018-11-05 02:46:23" />
# 	<numplays>4</numplays>							</item>
# 		<item objecttype="thing" objectid="262906" subtype="boardgame" collid="55557593">
# 	<name sortindex="1">Warhammer Underworlds: Nightvault – Garrek’s Reavers</name>
# 		<yearpublished>2018</yearpublished>			https://cf.geekdo-images.com/iLFCEO9a9R7QoDGP0mk67w__original/img/UXsYtioiGO_LDVUWc9TrfldpG6Y=/0x0/filters:format(jpeg)/pic4503460.jpg
# 		<thumbnail>https://cf.geekdo-images.com/iLFCEO9a9R7QoDGP0mk67w__thumb/img/tfFeKm9XeAYnVxhx2TbTVjbvwk4=/fit-in/200x150/filters:strip_icc()/pic4503460.jpg</thumbnail>
# 		<stats minplayers="2"																	maxplayers="2"																	minplaytime="30"																	maxplaytime="60"																	playingtime="60"																	numowned="268" >
# 				<rating value="N/A">			<usersrated value="39" />			<average value="7.80443" />
# 			<bayesaverage value="5.54355" />			<stddev value="1.35681" />
# 			<median value="0" />			<ranks>
# 												<rank type="subtype" id="1" name="boardgame" friendlyname="Board Game Rank" value="Not Ranked" bayesaverage="5.54355" />
# 											</ranks>		</rating>
# 			</stats>	<status own="1" prevowned="0" fortrade="0" want="0" wanttoplay="0" wanttobuy="0" wishlist="0"  preordered="0" lastmodified="2018-11-05 02:46:34" />
# 	<numplays>0</numplays>							</item>
# 		<item objecttype="thing" objectid="233867" subtype="boardgame" collid="77843246">
# 	<name sortindex="1">Welcome To...</name>
# 		<yearpublished>2018</yearpublished>			https://cf.geekdo-images.com/g4XmxyKhNVdhC3QPd1purQ__original/img/pb6XFQZFUNOr6OPysOHB3usVDFk=/0x0/filters:format(jpeg)/pic3761012.jpg
# 		<thumbnail>https://cf.geekdo-images.com/g4XmxyKhNVdhC3QPd1purQ__thumb/img/e3bCyIvM1IOGFYnKGj2jIn5mbKY=/fit-in/200x150/filters:strip_icc()/pic3761012.jpg</thumbnail>
# 		<stats minplayers="1"																	maxplayers="100"																	minplaytime="25"																	maxplaytime="25"																	playingtime="25"																	numowned="28895" >
# 				<rating value="N/A">			<usersrated value="18499" />			<average value="7.61106" />
# 			<bayesaverage value="7.41975" />			<stddev value="1.1106" />
# 			<median value="0" />			<ranks>
# 												<rank type="subtype" id="1" name="boardgame" friendlyname="Board Game Rank" value="128" bayesaverage="7.41975" />
# 																<rank type="family" id="5499" name="familygames" friendlyname="Family Game Rank" value="17" bayesaverage="7.46529" />
# 											</ranks>		</rating>
# 			</stats>	<status own="1" prevowned="0" fortrade="0" want="0" wanttoplay="0" wanttobuy="0" wishlist="0"  preordered="0" lastmodified="2021-01-01 12:22:56" />
# 	<numplays>0</numplays>							</item>
# 		<item objecttype="thing" objectid="266192" subtype="boardgame" collid="65879115">
# 	<name sortindex="1">Wingspan</name>
# 		<yearpublished>2019</yearpublished>			https://cf.geekdo-images.com/yLZJCVLlIx4c7eJEWUNJ7w__original/img/cI782Zis9cT66j2MjSHKJGnFPNw=/0x0/filters:format(jpeg)/pic4458123.jpg
# 		<thumbnail>https://cf.geekdo-images.com/yLZJCVLlIx4c7eJEWUNJ7w__thumb/img/VNToqgS2-pOGU6MuvIkMPKn_y-s=/fit-in/200x150/filters:strip_icc()/pic4458123.jpg</thumbnail>
# 		<stats minplayers="1"																	maxplayers="5"																	minplaytime="40"																	maxplaytime="70"																	playingtime="70"																	numowned="66796" >
# 				<rating value="N/A">			<usersrated value="46449" />			<average value="8.11476" />
# 			<bayesaverage value="7.948" />			<stddev value="1.34291" />
# 			<median value="0" />			<ranks>
# 												<rank type="subtype" id="1" name="boardgame" friendlyname="Board Game Rank" value="20" bayesaverage="7.948" />
# 																<rank type="family" id="5497" name="strategygames" friendlyname="Strategy Game Rank" value="22" bayesaverage="7.89969" />
# 								<rank type="family" id="5499" name="familygames" friendlyname="Family Game Rank" value="1" bayesaverage="7.96328" />
# 											</ranks>		</rating>
# 			</stats>	<status own="1" prevowned="0" fortrade="0" want="0" wanttoplay="0" wanttobuy="0" wishlist="0"  preordered="0" lastmodified="2019-11-18 08:17:31" />
# 	<numplays>0</numplays>							</item>
#
# </items>
# [('68448', None),
#  ('173346', None),
#  ('31260', None),
#  ('13464', None),
#  ('205637', None),
#  ('230802', '8'),
#  ('212445', None),
#  ('318472', None),
#  ('170216', None),
#  ('174506', None),
#  ('174801', None),
#  ('224517', None),
#  ('171131', None),
#  ('822', None),
#  ('21385', None),
#  ('13', None),
#  ('926', None),
#  ('325', None),
#  ('553', None),
#  ('478', None),
#  ('178900', None),
#  ('198773', None),
#  ('39463', None),
#  ('225694', None),
#  ('104162', '6'),
#  ('36218', None),
#  ('5177', None),
#  ('283355', None),
#  ('157958', None),
#  ('72125', None),
#  ('246900', '9'),
#  ('175621', None),
#  ('177736', None),
#  ('199478', None),
#  ('169124', None),
#  ('175155', '8'),
#  ('37904', None),
#  ('31481', None),
#  ('23730', None),
#  ('291457', None),
#  ('193738', None),
#  ('227460', None),
#  ('198994', None),
#  ('154597', None),
#  ('859', None),
#  ('154203', None),
#  ('206051', None),
#  ('84159', None),
#  ('257501', None),
#  ('257', None),
#  ('70323', None),
#  ('281960', None),
#  ('823', None),
#  ('143884', None),
#  ('463', None),
#  ('205059', None),
#  ('1927', None),
#  ('3943', None),
#  ('1621', None),
#  ('164928', None),
#  ('30549', None),
#  ('161936', None),
#  ('221107', None),
#  ('218603', None),
#  ('2651', None),
#  ('183006', None),
#  ('28143', None),
#  ('41114', None),
#  ('181', None),
#  ('121921', None),
#  ('18', None),
#  ('237182', None),
#  ('438', None),
#  ('169786', None),
#  ('199727', None),
#  ('242277', None),
#  ('298638', None),
#  ('8222', None),
#  ('148228', None),
#  ('187645', None),
#  ('226840', None),
#  ('1897', None),
#  ('146508', None),
#  ('189035', None),
#  ('229853', None),
#  ('120677', None),
#  ('167791', '9'),
#  ('247030', None),
#  ('244522', None),
#  ('182028', None),
#  ('14996', None),
#  ('276894', None),
#  ('148951', None),
#  ('233078', '9'),
#  ('126163', None),
#  ('122328', None),
#  ('115746', None),
#  ('228051', None),
#  ('261594', None),
#  ('262906', None),
#  ('233867', None),
#  ('266192', None)]

# %%
games = get_games_from_game_ids(game_ids)
games_et = get_xml_string_from_response(games)
# Out:
# https://www.boardgamegeek.com/xmlapi2/thing?id=68448,173346,31260,13464,205637,230802,212445,318472,170216,174506,174801,224517,171131,822,21385,13,926,325,553,478,178900,198773,39463,225694,104162,36218,5177,283355,157958,72125,246900,175621,177736,199478,169124,175155,37904,31481,23730,291457,193738,227460,198994,154597,859,154203,206051,84159,257501,257,70323,281960,823,143884,463,205059,1927,3943,1621,164928,30549,161936,221107,218603,2651,183006,28143,41114,181,121921,18,237182,438,169786,199727,242277,298638,8222,148228,187645,226840,1897,146508,189035,229853,120677,167791,247030,244522,182028,14996,276894,148951,233078,126163,122328,115746,228051,261594,262906,233867,266192&stats=1

# %% [markdown]
# # sqlalchemy

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite:///db.sqlite', echo=True)

# %%
from sqlalchemy.ext.declarative import declarative_base

# %%
Base = declarative_base()

# %%
from sqlalchemy import Column, Integer, String

# %%
class User(Base):
    __tablename__ = 'users'
    id = Column(Integer, primary_key=True)
    name = Column(String, unique=True)

# %%
class UserGame(Base):
    __tablename__ = 'user_games'
    id = Column(Integer, primary_key=True)
    user_id = Column(Integer, nullable=False)
    bgg_game_id = Column(Integer, nullable=False)
    user_rating = Column(Integer)

# %%
class Game(Base):
    __tablename__ = 'games'
    id = Column(Integer, primary_key=True)
    bgg_game_id = Column(Integer, nullable=False, unique=True)
    title = Column(String, nullable=False)
    type = Column(String, nullable=False)
    year_published = Column(Integer, nullable=False)
    description = Column(String, nullable=False)
    image_url = Column(String, nullable=False)
    thumbnail_url = Column(String, nullable=False)
    min_players = Column(Integer, nullable=False)
    max_players = Column(Integer, nullable=False)
    playing_time = Column(Integer, nullable=False)
    min_playing_time = Column(Integer, nullable=False)
    max_playing_time = Column(Integer, nullable=False)
    min_age = Column(Integer, nullable=False)
    average_rating = Column(Integer, nullable=False)
    bayes_average_rating = Column(Integer, nullable=False)
    board_game_rank = Column(Integer, nullable=False)
    designers = Column(String, nullable=False)
    mechanics = Column(String, nullable=False)
    categories = Column(String, nullable=False)
    user_suggested_best_number_of_players = Column(String, nullable=False)
    user_suggested_recommended_number_of_players = Column(String, nullable=False)

# %%
Base.metadata.create_all(engine)
# Out:
# 2021-05-18 20:31:07,175 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2021-05-18 20:31:07,176 INFO sqlalchemy.engine.base.Engine ()
# 2021-05-18 20:31:07,179 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2021-05-18 20:31:07,181 INFO sqlalchemy.engine.base.Engine ()
# 2021-05-18 20:31:07,183 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("users")
# 2021-05-18 20:31:07,184 INFO sqlalchemy.engine.base.Engine ()
# 2021-05-18 20:31:07,186 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("users")
# 2021-05-18 20:31:07,187 INFO sqlalchemy.engine.base.Engine ()
# 2021-05-18 20:31:07,189 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("user_games")
# 2021-05-18 20:31:07,191 INFO sqlalchemy.engine.base.Engine ()
# 2021-05-18 20:31:07,192 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("user_games")
# 2021-05-18 20:31:07,193 INFO sqlalchemy.engine.base.Engine ()
# 2021-05-18 20:31:07,195 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("games")
# 2021-05-18 20:31:07,196 INFO sqlalchemy.engine.base.Engine ()
# 2021-05-18 20:31:07,197 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("games")
# 2021-05-18 20:31:07,198 INFO sqlalchemy.engine.base.Engine ()
# 2021-05-18 20:31:07,201 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE users (
# 	id INTEGER NOT NULL,
# 	name VARCHAR,
# 	PRIMARY KEY (id),
# 	UNIQUE (name)
# )
#
#
# 2021-05-18 20:31:07,202 INFO sqlalchemy.engine.base.Engine ()
# 2021-05-18 20:31:07,213 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-05-18 20:31:07,214 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE user_games (
# 	id INTEGER NOT NULL,
# 	user_id INTEGER NOT NULL,
# 	bgg_game_id INTEGER NOT NULL,
# 	user_rating INTEGER,
# 	PRIMARY KEY (id)
# )
#
#
# 2021-05-18 20:31:07,216 INFO sqlalchemy.engine.base.Engine ()
# 2021-05-18 20:31:07,227 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-05-18 20:31:07,229 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE games (
# 	id INTEGER NOT NULL,
# 	bgg_game_id INTEGER NOT NULL,
# 	title VARCHAR NOT NULL,
# 	type VARCHAR NOT NULL,
# 	year_published INTEGER NOT NULL,
# 	description VARCHAR NOT NULL,
# 	image_url VARCHAR NOT NULL,
# 	thumbnail_url VARCHAR NOT NULL,
# 	min_players INTEGER NOT NULL,
# 	max_players INTEGER NOT NULL,
# 	playing_time INTEGER NOT NULL,
# 	min_playing_time INTEGER NOT NULL,
# 	max_playing_time INTEGER NOT NULL,
# 	min_age INTEGER NOT NULL,
# 	average_rating INTEGER NOT NULL,
# 	bayes_average_rating INTEGER NOT NULL,
# 	board_game_rank INTEGER NOT NULL,
# 	designers VARCHAR NOT NULL,
# 	mechanics VARCHAR NOT NULL,
# 	categories VARCHAR NOT NULL,
# 	user_suggested_best_number_of_players VARCHAR NOT NULL,
# 	user_suggested_recommended_number_of_players VARCHAR NOT NULL,
# 	PRIMARY KEY (id),
# 	UNIQUE (bgg_game_id)
# )
#
#
# 2021-05-18 20:31:07,231 INFO sqlalchemy.engine.base.Engine ()
# 2021-05-18 20:31:07,246 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
from sqlalchemy.orm import sessionmaker
Session = sessionmaker(bind=engine)

# %%
session = Session()

# %%
session = Session()

def insert_user_into_database(username, session):
    user = User(name=username)
    session.add(user)
    session.commit()

    
def check_user_in_database(username):
    user_in_database = session.query(User).filter(User.name==username).first()
    if user_in_database is None:
        return False
    return True

if not check_user_in_database('bobbaganush'):
    insert_user_into_database('bobbaganush', session)
# Out:
# 2021-05-20 19:42:05,457 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2021-05-20 19:42:05,459 INFO sqlalchemy.engine.base.Engine SELECT users.id AS users_id, users.name AS users_name
# FROM users
# WHERE users.name = ?
#  LIMIT ? OFFSET ?
# 2021-05-20 19:42:05,461 INFO sqlalchemy.engine.base.Engine ('bobbaganush', 1, 0)

# %%
session = Session()

def insert_user_games_into_database(username, data_list, session):
    user_id_from_name = session.query(User.id).filter(User.name==username).first()
    for user_game in data_list:
        ug = UserGame(user_id=user_id_from_name[0], bgg_game_id=user_game[0], user_rating=user_game[1])
        session.add(ug)
        
    session.commit()

insert_user_games_into_database('bobbaganush', user_games, session)
# Out:
# 2021-05-19 22:38:47,489 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2021-05-19 22:38:47,491 INFO sqlalchemy.engine.base.Engine SELECT users.id AS users_id
# FROM users
# WHERE users.name = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:38:47,492 INFO sqlalchemy.engine.base.Engine ('bobbaganush', 1, 0)
# 2021-05-19 22:38:47,501 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,502 INFO sqlalchemy.engine.base.Engine (1, '68448', None)
# 2021-05-19 22:38:47,504 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,506 INFO sqlalchemy.engine.base.Engine (1, '173346', None)
# 2021-05-19 22:38:47,507 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,508 INFO sqlalchemy.engine.base.Engine (1, '31260', None)
# 2021-05-19 22:38:47,510 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,511 INFO sqlalchemy.engine.base.Engine (1, '13464', None)
# 2021-05-19 22:38:47,512 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,514 INFO sqlalchemy.engine.base.Engine (1, '205637', None)
# 2021-05-19 22:38:47,515 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,516 INFO sqlalchemy.engine.base.Engine (1, '230802', '8')
# 2021-05-19 22:38:47,517 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,521 INFO sqlalchemy.engine.base.Engine (1, '170216', None)
# 2021-05-19 22:38:47,522 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,523 INFO sqlalchemy.engine.base.Engine (1, '174506', None)
# 2021-05-19 22:38:47,524 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,525 INFO sqlalchemy.engine.base.Engine (1, '174801', None)
# 2021-05-19 22:38:47,526 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,527 INFO sqlalchemy.engine.base.Engine (1, '224517', None)
# 2021-05-19 22:38:47,528 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,529 INFO sqlalchemy.engine.base.Engine (1, '171131', None)
# 2021-05-19 22:38:47,538 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,541 INFO sqlalchemy.engine.base.Engine (1, '822', None)
# 2021-05-19 22:38:47,542 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,544 INFO sqlalchemy.engine.base.Engine (1, '21385', None)
# 2021-05-19 22:38:47,546 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,548 INFO sqlalchemy.engine.base.Engine (1, '13', None)
# 2021-05-19 22:38:47,550 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,551 INFO sqlalchemy.engine.base.Engine (1, '926', None)
# 2021-05-19 22:38:47,552 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,553 INFO sqlalchemy.engine.base.Engine (1, '325', None)
# 2021-05-19 22:38:47,555 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,560 INFO sqlalchemy.engine.base.Engine (1, '553', None)
# 2021-05-19 22:38:47,565 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,568 INFO sqlalchemy.engine.base.Engine (1, '478', None)
# 2021-05-19 22:38:47,576 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,580 INFO sqlalchemy.engine.base.Engine (1, '178900', None)
# 2021-05-19 22:38:47,581 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,582 INFO sqlalchemy.engine.base.Engine (1, '198773', None)
# 2021-05-19 22:38:47,583 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,583 INFO sqlalchemy.engine.base.Engine (1, '39463', None)
# 2021-05-19 22:38:47,584 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,586 INFO sqlalchemy.engine.base.Engine (1, '225694', None)
# 2021-05-19 22:38:47,590 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,592 INFO sqlalchemy.engine.base.Engine (1, '104162', '6')
# 2021-05-19 22:38:47,594 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,595 INFO sqlalchemy.engine.base.Engine (1, '36218', None)
# 2021-05-19 22:38:47,599 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,600 INFO sqlalchemy.engine.base.Engine (1, '5177', None)
# 2021-05-19 22:38:47,602 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,617 INFO sqlalchemy.engine.base.Engine (1, '283355', None)
# 2021-05-19 22:38:47,618 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,619 INFO sqlalchemy.engine.base.Engine (1, '157958', None)
# 2021-05-19 22:38:47,623 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,629 INFO sqlalchemy.engine.base.Engine (1, '72125', None)
# 2021-05-19 22:38:47,634 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,635 INFO sqlalchemy.engine.base.Engine (1, '246900', '9')
# 2021-05-19 22:38:47,637 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,639 INFO sqlalchemy.engine.base.Engine (1, '175621', None)
# 2021-05-19 22:38:47,649 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,659 INFO sqlalchemy.engine.base.Engine (1, '177736', None)
# 2021-05-19 22:38:47,668 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,677 INFO sqlalchemy.engine.base.Engine (1, '199478', None)
# 2021-05-19 22:38:47,680 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,681 INFO sqlalchemy.engine.base.Engine (1, '169124', None)
# 2021-05-19 22:38:47,683 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,684 INFO sqlalchemy.engine.base.Engine (1, '175155', '8')
# 2021-05-19 22:38:47,691 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,692 INFO sqlalchemy.engine.base.Engine (1, '37904', None)
# 2021-05-19 22:38:47,693 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,694 INFO sqlalchemy.engine.base.Engine (1, '31481', None)
# 2021-05-19 22:38:47,697 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,699 INFO sqlalchemy.engine.base.Engine (1, '23730', None)
# 2021-05-19 22:38:47,700 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,701 INFO sqlalchemy.engine.base.Engine (1, '291457', None)
# 2021-05-19 22:38:47,705 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,708 INFO sqlalchemy.engine.base.Engine (1, '193738', None)
# 2021-05-19 22:38:47,715 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,716 INFO sqlalchemy.engine.base.Engine (1, '227460', None)
# 2021-05-19 22:38:47,718 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,719 INFO sqlalchemy.engine.base.Engine (1, '198994', None)
# 2021-05-19 22:38:47,721 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,721 INFO sqlalchemy.engine.base.Engine (1, '154597', None)
# 2021-05-19 22:38:47,723 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,724 INFO sqlalchemy.engine.base.Engine (1, '859', None)
# 2021-05-19 22:38:47,725 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,728 INFO sqlalchemy.engine.base.Engine (1, '154203', None)
# 2021-05-19 22:38:47,729 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,730 INFO sqlalchemy.engine.base.Engine (1, '206051', None)
# 2021-05-19 22:38:47,732 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,732 INFO sqlalchemy.engine.base.Engine (1, '84159', None)
# 2021-05-19 22:38:47,734 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,735 INFO sqlalchemy.engine.base.Engine (1, '257501', None)
# 2021-05-19 22:38:47,738 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,739 INFO sqlalchemy.engine.base.Engine (1, '257', None)
# 2021-05-19 22:38:47,740 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,741 INFO sqlalchemy.engine.base.Engine (1, '70323', None)
# 2021-05-19 22:38:47,743 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,747 INFO sqlalchemy.engine.base.Engine (1, '281960', None)
# 2021-05-19 22:38:47,748 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,749 INFO sqlalchemy.engine.base.Engine (1, '823', None)
# 2021-05-19 22:38:47,751 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,753 INFO sqlalchemy.engine.base.Engine (1, '143884', None)
# 2021-05-19 22:38:47,755 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,757 INFO sqlalchemy.engine.base.Engine (1, '463', None)
# 2021-05-19 22:38:47,763 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,765 INFO sqlalchemy.engine.base.Engine (1, '205059', None)
# 2021-05-19 22:38:47,767 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,769 INFO sqlalchemy.engine.base.Engine (1, '1927', None)
# 2021-05-19 22:38:47,771 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,777 INFO sqlalchemy.engine.base.Engine (1, '3943', None)
# 2021-05-19 22:38:47,779 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,781 INFO sqlalchemy.engine.base.Engine (1, '1621', None)
# 2021-05-19 22:38:47,784 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,786 INFO sqlalchemy.engine.base.Engine (1, '164928', None)
# 2021-05-19 22:38:47,787 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,789 INFO sqlalchemy.engine.base.Engine (1, '30549', None)
# 2021-05-19 22:38:47,791 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,792 INFO sqlalchemy.engine.base.Engine (1, '161936', None)
# 2021-05-19 22:38:47,793 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,794 INFO sqlalchemy.engine.base.Engine (1, '221107', None)
# 2021-05-19 22:38:47,796 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,797 INFO sqlalchemy.engine.base.Engine (1, '218603', None)
# 2021-05-19 22:38:47,799 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,801 INFO sqlalchemy.engine.base.Engine (1, '2651', None)
# 2021-05-19 22:38:47,802 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,806 INFO sqlalchemy.engine.base.Engine (1, '183006', None)
# 2021-05-19 22:38:47,810 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,815 INFO sqlalchemy.engine.base.Engine (1, '28143', None)
# 2021-05-19 22:38:47,817 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,818 INFO sqlalchemy.engine.base.Engine (1, '41114', None)
# 2021-05-19 22:38:47,819 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,820 INFO sqlalchemy.engine.base.Engine (1, '181', None)
# 2021-05-19 22:38:47,822 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,823 INFO sqlalchemy.engine.base.Engine (1, '121921', None)
# 2021-05-19 22:38:47,825 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,826 INFO sqlalchemy.engine.base.Engine (1, '18', None)
# 2021-05-19 22:38:47,827 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,829 INFO sqlalchemy.engine.base.Engine (1, '237182', None)
# 2021-05-19 22:38:47,830 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,831 INFO sqlalchemy.engine.base.Engine (1, '438', None)
# 2021-05-19 22:38:47,835 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,836 INFO sqlalchemy.engine.base.Engine (1, '169786', None)
# 2021-05-19 22:38:47,842 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,844 INFO sqlalchemy.engine.base.Engine (1, '199727', None)
# 2021-05-19 22:38:47,849 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,856 INFO sqlalchemy.engine.base.Engine (1, '242277', None)
# 2021-05-19 22:38:47,858 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,865 INFO sqlalchemy.engine.base.Engine (1, '298638', None)
# 2021-05-19 22:38:47,869 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,872 INFO sqlalchemy.engine.base.Engine (1, '8222', None)
# 2021-05-19 22:38:47,873 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,875 INFO sqlalchemy.engine.base.Engine (1, '148228', None)
# 2021-05-19 22:38:47,876 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,877 INFO sqlalchemy.engine.base.Engine (1, '187645', None)
# 2021-05-19 22:38:47,880 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,881 INFO sqlalchemy.engine.base.Engine (1, '226840', None)
# 2021-05-19 22:38:47,882 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,883 INFO sqlalchemy.engine.base.Engine (1, '1897', None)
# 2021-05-19 22:38:47,885 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,887 INFO sqlalchemy.engine.base.Engine (1, '146508', None)
# 2021-05-19 22:38:47,889 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,891 INFO sqlalchemy.engine.base.Engine (1, '189035', None)
# 2021-05-19 22:38:47,892 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,893 INFO sqlalchemy.engine.base.Engine (1, '229853', None)
# 2021-05-19 22:38:47,894 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,896 INFO sqlalchemy.engine.base.Engine (1, '120677', None)
# 2021-05-19 22:38:47,897 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,898 INFO sqlalchemy.engine.base.Engine (1, '167791', '9')
# 2021-05-19 22:38:47,899 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,900 INFO sqlalchemy.engine.base.Engine (1, '247030', None)
# 2021-05-19 22:38:47,903 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,904 INFO sqlalchemy.engine.base.Engine (1, '244522', None)
# 2021-05-19 22:38:47,906 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,909 INFO sqlalchemy.engine.base.Engine (1, '182028', None)
# 2021-05-19 22:38:47,915 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,915 INFO sqlalchemy.engine.base.Engine (1, '14996', None)
# 2021-05-19 22:38:47,917 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,919 INFO sqlalchemy.engine.base.Engine (1, '276894', None)
# 2021-05-19 22:38:47,920 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,921 INFO sqlalchemy.engine.base.Engine (1, '148951', None)
# 2021-05-19 22:38:47,923 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,924 INFO sqlalchemy.engine.base.Engine (1, '233078', '9')
# 2021-05-19 22:38:47,925 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,926 INFO sqlalchemy.engine.base.Engine (1, '126163', None)
# 2021-05-19 22:38:47,928 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,929 INFO sqlalchemy.engine.base.Engine (1, '122328', None)
# 2021-05-19 22:38:47,930 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,931 INFO sqlalchemy.engine.base.Engine (1, '115746', None)
# 2021-05-19 22:38:47,933 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,934 INFO sqlalchemy.engine.base.Engine (1, '228051', None)
# 2021-05-19 22:38:47,935 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,936 INFO sqlalchemy.engine.base.Engine (1, '261594', None)
# 2021-05-19 22:38:47,937 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,938 INFO sqlalchemy.engine.base.Engine (1, '262906', None)
# 2021-05-19 22:38:47,939 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,951 INFO sqlalchemy.engine.base.Engine (1, '233867', None)
# 2021-05-19 22:38:47,957 INFO sqlalchemy.engine.base.Engine INSERT INTO user_games (user_id, bgg_game_id, user_rating) VALUES (?, ?, ?)
# 2021-05-19 22:38:47,958 INFO sqlalchemy.engine.base.Engine (1, '266192', None)
# 2021-05-19 22:38:47,962 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
session = Session()
l = []
for game in games_et:
    bg = BoardgameXMLParser(game)
    bg_id_already_in_database = session.query(Game.bgg_game_id).filter(Game.bgg_game_id==bg.id).first() is not None
    if not bg_id_already_in_database:
        bg_sql = Game(
                     bgg_game_id=bg.id,
                     title=bg.title,
                     type=bg.type,
                     description=bg.description,
                     year_published=bg.year_published,
                     image_url=bg.image,
                     thumbnail_url=bg.thumbnail,
                     min_players=bg.min_players_from_creators,
                     max_players=bg.max_players_from_creators,
                     playing_time=bg.playing_time,
                     min_playing_time=bg.min_playing_time,
                     max_playing_time=bg.max_playing_time,
                     min_age=bg.min_age,
                     average_rating=bg.average_rating,
                     bayes_average_rating=bg.bayes_average_rating,
                     board_game_rank=bg.board_game_rank,
                     designers=bg.designers,
                     mechanics=bg.mechanics,
                     categories=bg.categories,
                     user_suggested_best_number_of_players=bg.user_suggested_best_number_of_players,
                     user_suggested_recommended_number_of_players=bg.user_suggested_recommended_number_of_players
                     )
        l.append(bg_sql)
    else:
        print('game already in games.')
session.add_all(l)
    
session.commit()
# Out:
# 2021-05-19 22:18:22,382 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2021-05-19 22:18:22,384 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:22,385 INFO sqlalchemy.engine.base.Engine ('68448', 1, 0)
# game already in games.
# 2021-05-19 22:18:22,396 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:22,397 INFO sqlalchemy.engine.base.Engine ('173346', 1, 0)
# game already in games.
# 2021-05-19 22:18:22,408 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:22,410 INFO sqlalchemy.engine.base.Engine ('31260', 1, 0)
# game already in games.
# 2021-05-19 22:18:22,421 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:22,422 INFO sqlalchemy.engine.base.Engine ('13464', 1, 0)
# game already in games.
# 2021-05-19 22:18:22,447 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:22,448 INFO sqlalchemy.engine.base.Engine ('205637', 1, 0)
# game already in games.
# 2021-05-19 22:18:22,462 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:22,468 INFO sqlalchemy.engine.base.Engine ('230802', 1, 0)
# game already in games.
# 2021-05-19 22:18:22,492 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:22,493 INFO sqlalchemy.engine.base.Engine ('170216', 1, 0)
# game already in games.
# 2021-05-19 22:18:22,530 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:22,539 INFO sqlalchemy.engine.base.Engine ('174506', 1, 0)
# game already in games.
# 2021-05-19 22:18:22,551 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:22,554 INFO sqlalchemy.engine.base.Engine ('174801', 1, 0)
# game already in games.
# 2021-05-19 22:18:22,573 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:22,574 INFO sqlalchemy.engine.base.Engine ('224517', 1, 0)
# game already in games.
# 2021-05-19 22:18:22,601 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:22,603 INFO sqlalchemy.engine.base.Engine ('171131', 1, 0)
# game already in games.
# 2021-05-19 22:18:22,616 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:22,617 INFO sqlalchemy.engine.base.Engine ('822', 1, 0)
# game already in games.
# 2021-05-19 22:18:22,641 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:22,642 INFO sqlalchemy.engine.base.Engine ('21385', 1, 0)
# game already in games.
# 2021-05-19 22:18:22,670 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:22,671 INFO sqlalchemy.engine.base.Engine ('13', 1, 0)
# game already in games.
# 2021-05-19 22:18:22,683 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:22,684 INFO sqlalchemy.engine.base.Engine ('926', 1, 0)
# game already in games.
# 2021-05-19 22:18:22,715 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:22,727 INFO sqlalchemy.engine.base.Engine ('325', 1, 0)
# game already in games.
# 2021-05-19 22:18:22,742 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:22,744 INFO sqlalchemy.engine.base.Engine ('553', 1, 0)
# game already in games.
# 2021-05-19 22:18:22,762 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:22,763 INFO sqlalchemy.engine.base.Engine ('478', 1, 0)
# game already in games.
# 2021-05-19 22:18:22,778 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:22,779 INFO sqlalchemy.engine.base.Engine ('178900', 1, 0)
# game already in games.
# 2021-05-19 22:18:22,795 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:22,801 INFO sqlalchemy.engine.base.Engine ('198773', 1, 0)
# game already in games.
# 2021-05-19 22:18:22,816 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:22,817 INFO sqlalchemy.engine.base.Engine ('39463', 1, 0)
# game already in games.
# 2021-05-19 22:18:22,834 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:22,839 INFO sqlalchemy.engine.base.Engine ('225694', 1, 0)
# game already in games.
# 2021-05-19 22:18:22,860 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:22,869 INFO sqlalchemy.engine.base.Engine ('104162', 1, 0)
# game already in games.
# 2021-05-19 22:18:22,888 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:22,889 INFO sqlalchemy.engine.base.Engine ('36218', 1, 0)
# game already in games.
# 2021-05-19 22:18:22,914 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:22,915 INFO sqlalchemy.engine.base.Engine ('5177', 1, 0)
# game already in games.
# 2021-05-19 22:18:22,947 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:22,955 INFO sqlalchemy.engine.base.Engine ('283355', 1, 0)
# game already in games.
# 2021-05-19 22:18:22,972 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:22,973 INFO sqlalchemy.engine.base.Engine ('157958', 1, 0)
# game already in games.
# 2021-05-19 22:18:22,995 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:22,997 INFO sqlalchemy.engine.base.Engine ('72125', 1, 0)
# game already in games.
# 2021-05-19 22:18:23,011 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:23,022 INFO sqlalchemy.engine.base.Engine ('246900', 1, 0)
# game already in games.
# 2021-05-19 22:18:23,046 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:23,048 INFO sqlalchemy.engine.base.Engine ('175621', 1, 0)
# game already in games.
# 2021-05-19 22:18:23,070 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:23,074 INFO sqlalchemy.engine.base.Engine ('177736', 1, 0)
# game already in games.
# 2021-05-19 22:18:23,091 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:23,109 INFO sqlalchemy.engine.base.Engine ('199478', 1, 0)
# game already in games.
# 2021-05-19 22:18:23,129 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:23,139 INFO sqlalchemy.engine.base.Engine ('169124', 1, 0)
# game already in games.
# 2021-05-19 22:18:23,171 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:23,176 INFO sqlalchemy.engine.base.Engine ('175155', 1, 0)
# game already in games.
# 2021-05-19 22:18:23,216 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:23,218 INFO sqlalchemy.engine.base.Engine ('37904', 1, 0)
# game already in games.
# 2021-05-19 22:18:23,251 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:23,254 INFO sqlalchemy.engine.base.Engine ('31481', 1, 0)
# game already in games.
# 2021-05-19 22:18:23,284 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:23,290 INFO sqlalchemy.engine.base.Engine ('23730', 1, 0)
# game already in games.
# 2021-05-19 22:18:23,311 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:23,312 INFO sqlalchemy.engine.base.Engine ('291457', 1, 0)
# game already in games.
# 2021-05-19 22:18:23,333 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:23,336 INFO sqlalchemy.engine.base.Engine ('193738', 1, 0)
# game already in games.
# 2021-05-19 22:18:23,365 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:23,371 INFO sqlalchemy.engine.base.Engine ('227460', 1, 0)
# game already in games.
# 2021-05-19 22:18:23,431 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:23,434 INFO sqlalchemy.engine.base.Engine ('198994', 1, 0)
# game already in games.
# 2021-05-19 22:18:23,483 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:23,485 INFO sqlalchemy.engine.base.Engine ('154597', 1, 0)
# game already in games.
# 2021-05-19 22:18:23,529 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:23,532 INFO sqlalchemy.engine.base.Engine ('859', 1, 0)
# game already in games.
# 2021-05-19 22:18:23,575 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:23,579 INFO sqlalchemy.engine.base.Engine ('154203', 1, 0)
# game already in games.
# 2021-05-19 22:18:23,596 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:23,597 INFO sqlalchemy.engine.base.Engine ('206051', 1, 0)
# game already in games.
# 2021-05-19 22:18:23,630 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:23,635 INFO sqlalchemy.engine.base.Engine ('84159', 1, 0)
# game already in games.
# 2021-05-19 22:18:23,652 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:23,656 INFO sqlalchemy.engine.base.Engine ('257501', 1, 0)
# game already in games.
# 2021-05-19 22:18:23,683 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:23,684 INFO sqlalchemy.engine.base.Engine ('257', 1, 0)
# game already in games.
# 2021-05-19 22:18:23,717 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:23,720 INFO sqlalchemy.engine.base.Engine ('70323', 1, 0)
# game already in games.
# 2021-05-19 22:18:23,747 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:23,748 INFO sqlalchemy.engine.base.Engine ('281960', 1, 0)
# game already in games.
# 2021-05-19 22:18:23,804 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:23,813 INFO sqlalchemy.engine.base.Engine ('823', 1, 0)
# game already in games.
# 2021-05-19 22:18:23,866 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:23,883 INFO sqlalchemy.engine.base.Engine ('143884', 1, 0)
# game already in games.
# 2021-05-19 22:18:23,933 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:23,935 INFO sqlalchemy.engine.base.Engine ('463', 1, 0)
# game already in games.
# 2021-05-19 22:18:23,978 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:23,979 INFO sqlalchemy.engine.base.Engine ('205059', 1, 0)
# game already in games.
# 2021-05-19 22:18:24,028 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:24,030 INFO sqlalchemy.engine.base.Engine ('1927', 1, 0)
# game already in games.
# 2021-05-19 22:18:24,045 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:24,048 INFO sqlalchemy.engine.base.Engine ('3943', 1, 0)
# game already in games.
# 2021-05-19 22:18:24,080 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:24,082 INFO sqlalchemy.engine.base.Engine ('1621', 1, 0)
# game already in games.
# 2021-05-19 22:18:24,102 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:24,108 INFO sqlalchemy.engine.base.Engine ('164928', 1, 0)
# game already in games.
# 2021-05-19 22:18:24,134 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:24,136 INFO sqlalchemy.engine.base.Engine ('30549', 1, 0)
# game already in games.
# 2021-05-19 22:18:24,155 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:24,159 INFO sqlalchemy.engine.base.Engine ('161936', 1, 0)
# game already in games.
# 2021-05-19 22:18:24,172 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:24,173 INFO sqlalchemy.engine.base.Engine ('221107', 1, 0)
# game already in games.
# 2021-05-19 22:18:24,184 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:24,185 INFO sqlalchemy.engine.base.Engine ('218603', 1, 0)
# game already in games.
# 2021-05-19 22:18:24,204 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:24,205 INFO sqlalchemy.engine.base.Engine ('2651', 1, 0)
# game already in games.
# 2021-05-19 22:18:24,223 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:24,224 INFO sqlalchemy.engine.base.Engine ('183006', 1, 0)
# game already in games.
# 2021-05-19 22:18:24,249 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:24,251 INFO sqlalchemy.engine.base.Engine ('28143', 1, 0)
# game already in games.
# 2021-05-19 22:18:24,263 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:24,264 INFO sqlalchemy.engine.base.Engine ('41114', 1, 0)
# game already in games.
# 2021-05-19 22:18:24,283 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:24,285 INFO sqlalchemy.engine.base.Engine ('181', 1, 0)
# game already in games.
# 2021-05-19 22:18:24,295 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:24,296 INFO sqlalchemy.engine.base.Engine ('121921', 1, 0)
# game already in games.
# 2021-05-19 22:18:24,316 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:24,317 INFO sqlalchemy.engine.base.Engine ('18', 1, 0)
# game already in games.
# 2021-05-19 22:18:24,333 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:24,334 INFO sqlalchemy.engine.base.Engine ('237182', 1, 0)
# game already in games.
# 2021-05-19 22:18:24,351 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:24,352 INFO sqlalchemy.engine.base.Engine ('438', 1, 0)
# game already in games.
# 2021-05-19 22:18:24,390 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:24,392 INFO sqlalchemy.engine.base.Engine ('169786', 1, 0)
# game already in games.
# 2021-05-19 22:18:24,421 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:24,423 INFO sqlalchemy.engine.base.Engine ('199727', 1, 0)
# game already in games.
# 2021-05-19 22:18:24,441 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:24,442 INFO sqlalchemy.engine.base.Engine ('242277', 1, 0)
# game already in games.
# 2021-05-19 22:18:24,461 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:24,462 INFO sqlalchemy.engine.base.Engine ('298638', 1, 0)
# game already in games.
# 2021-05-19 22:18:24,476 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:24,484 INFO sqlalchemy.engine.base.Engine ('8222', 1, 0)
# game already in games.
# 2021-05-19 22:18:24,525 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:24,526 INFO sqlalchemy.engine.base.Engine ('148228', 1, 0)
# game already in games.
# 2021-05-19 22:18:24,566 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:24,569 INFO sqlalchemy.engine.base.Engine ('187645', 1, 0)
# game already in games.
# 2021-05-19 22:18:24,597 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:24,599 INFO sqlalchemy.engine.base.Engine ('226840', 1, 0)
# game already in games.
# 2021-05-19 22:18:24,611 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:24,612 INFO sqlalchemy.engine.base.Engine ('1897', 1, 0)
# game already in games.
# 2021-05-19 22:18:24,633 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:24,634 INFO sqlalchemy.engine.base.Engine ('146508', 1, 0)
# game already in games.
# 2021-05-19 22:18:24,662 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:24,664 INFO sqlalchemy.engine.base.Engine ('189035', 1, 0)
# game already in games.
# 2021-05-19 22:18:24,675 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:24,676 INFO sqlalchemy.engine.base.Engine ('229853', 1, 0)
# game already in games.
# 2021-05-19 22:18:24,696 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:24,697 INFO sqlalchemy.engine.base.Engine ('120677', 1, 0)
# game already in games.
# 2021-05-19 22:18:24,726 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:24,729 INFO sqlalchemy.engine.base.Engine ('167791', 1, 0)
# game already in games.
# 2021-05-19 22:18:24,745 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:24,746 INFO sqlalchemy.engine.base.Engine ('247030', 1, 0)
# game already in games.
# 2021-05-19 22:18:24,773 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:24,775 INFO sqlalchemy.engine.base.Engine ('244522', 1, 0)
# game already in games.
# 2021-05-19 22:18:24,809 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:24,812 INFO sqlalchemy.engine.base.Engine ('182028', 1, 0)
# game already in games.
# 2021-05-19 22:18:24,828 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:24,829 INFO sqlalchemy.engine.base.Engine ('14996', 1, 0)
# game already in games.
# 2021-05-19 22:18:24,852 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:24,853 INFO sqlalchemy.engine.base.Engine ('276894', 1, 0)
# game already in games.
# 2021-05-19 22:18:24,893 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:24,895 INFO sqlalchemy.engine.base.Engine ('148951', 1, 0)
# game already in games.
# 2021-05-19 22:18:24,919 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:24,920 INFO sqlalchemy.engine.base.Engine ('233078', 1, 0)
# game already in games.
# 2021-05-19 22:18:24,934 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:24,950 INFO sqlalchemy.engine.base.Engine ('126163', 1, 0)
# game already in games.
# 2021-05-19 22:18:24,973 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:24,975 INFO sqlalchemy.engine.base.Engine ('122328', 1, 0)
# game already in games.
# 2021-05-19 22:18:25,002 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:25,004 INFO sqlalchemy.engine.base.Engine ('115746', 1, 0)
# game already in games.
# 2021-05-19 22:18:25,017 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:25,018 INFO sqlalchemy.engine.base.Engine ('228051', 1, 0)
# game already in games.
# 2021-05-19 22:18:25,040 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:25,045 INFO sqlalchemy.engine.base.Engine ('261594', 1, 0)
# game already in games.
# 2021-05-19 22:18:25,049 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:25,050 INFO sqlalchemy.engine.base.Engine ('262906', 1, 0)
# game already in games.
# 2021-05-19 22:18:25,069 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:25,072 INFO sqlalchemy.engine.base.Engine ('233867', 1, 0)
# game already in games.
# 2021-05-19 22:18:25,083 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:25,084 INFO sqlalchemy.engine.base.Engine ('266192', 1, 0)
# game already in games.
# 2021-05-19 22:18:25,101 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-19 22:18:25,103 INFO sqlalchemy.engine.base.Engine ('163602', 1, 0)
# game already in games.
# 2021-05-19 22:18:25,105 INFO sqlalchemy.engine.base.Engine COMMIT
