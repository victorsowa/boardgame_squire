# %% [markdown]
# # parsing

# %%
import requests
import xml.etree.ElementTree as ET

import pandas as pd

# %%
BASE_URI = 'https://www.boardgamegeek.com/xmlapi2/'

def get_users_collection(username):
    collections_endpoint = BASE_URI + 'collection?'
    parameters = f'username={username}'
    return requests.get(collections_endpoint + parameters)

def get_xml_string_from_response(response): 
    return ET.fromstring(response.text)

def get_game_ids_from_collection(collection_element_tree):
    return [child.attrib['objectid'] for child in collection_element_tree]

def get_games_from_game_ids(game_ids):
    comma_seperated_game_ids = ','.join(game_ids)
    thing_endpoint = BASE_URI + 'thing?'
    parameters = f'id={comma_seperated_game_ids}&stats=1'
    print(thing_endpoint + parameters)
    return requests.get(thing_endpoint + parameters)

# %%
class BoardgameXMLParser:
    def __init__(self, board_game_element):
        self.board_game_element = board_game_element
        self.type = self.board_game_element.get('type')
        self.id = self.board_game_element.get('id')
        self.title = self._get_attribute_from_element('name[@type="primary"]', 'value')
        self.description = self.board_game_element.find('description').text
        self.image = self.board_game_element.find('image').text
        self.thumbnail = self.board_game_element.find('thumbnail').text
        self.year_published = self._get_attribute_from_element('yearpublished', 'value')
        self.min_players_from_creators = self._get_attribute_from_element('minplayers', 'value')
        self.max_players_from_creators = self._get_attribute_from_element('maxplayers', 'value')
        self.playing_time = self._get_attribute_from_element('playingtime', 'value')
        self.min_playing_time = self._get_attribute_from_element('minplaytime', 'value')
        self.max_playing_time = self._get_attribute_from_element('maxplaytime', 'value')
        self.min_age = self._get_attribute_from_element('minage', 'value')
        self.average_rating = self._get_attribute_from_element('.//average', 'value')
        self.bayes_average_rating = self._get_attribute_from_element('.//bayesaverage', 'value')
        self.board_game_rank = self._get_attribute_from_element('.//rank[@name="boardgame"]', 'value')  
        
        self.designers = self._get_attributes_from_element('link[@type="boardgamedesigner"]', 'value')
        self.mechanics = self._get_attributes_from_element('link[@type="boardgamemechanic"]', 'value')
        self.categories = self._get_attributes_from_element('link[@type="boardgamecategory"]', 'value')
        
        suggested_player_poll_element, suggested_players_total_votes = self._get_poll_results('poll[@name="suggested_numplayers"]')

        if suggested_players_total_votes == 0:
            self.user_suggested_best_number_of_players = ''
            self.user_suggested_recommended_number_of_players = ''
        else:   
            suggested_player_counts_df = self._get_suggested_player_counts_dataframe(suggested_player_poll_element)
            suggested_player_counts_df_with_poll_result = self._get_suggested_player_counts_data_with_realtive_amounts(suggested_player_counts_df)
            self.user_suggested_best_number_of_players = self._get_best_player_counts(suggested_player_counts_df_with_poll_result)
            self.user_suggested_recommended_number_of_players = self._get_recommended_player_counts(suggested_player_counts_df_with_poll_result)
        
    def _get_attribute_from_element(self, find_string, attribute_name):
        element = self.board_game_element.find(f'{find_string}')
        return element.get(attribute_name)
    
    def _get_attributes_from_element(self, find_string, attribute_name):
        elements = self.board_game_element.findall(f'{find_string}')
        attributes = [element.get(attribute_name) for element in elements]
        return '|'.join(attributes)
    
    def _get_poll_results(self, poll_pattern):
        poll = self.board_game_element.find(poll_pattern)
        return (poll.findall('results'), int(poll.get('totalvotes')))
    
    def _get_suggested_player_counts_dataframe(self, suggested_player_poll_element):
        options = []
        for option in suggested_player_poll_element:
            option_row = {}
            option_row['num_players'] = option.get('numplayers')
            option_row['best'] = int(option.find('result[@value="Best"]').get('numvotes'))
            option_row['recommended'] = int(option.find('result[@value="Recommended"]').get('numvotes'))
            option_row['not_recommended'] = int(option.find('result[@value="Not Recommended"]').get('numvotes'))
            options.append(option_row)
        return pd.DataFrame(options)
    
    def _get_suggested_player_counts_data_with_realtive_amounts(self, suggested_player_counts_df):
        df = suggested_player_counts_df
        df.loc[df['not_recommended'] > df['recommended'] + df['best'], 'poll_result'] = 'not_recommended'
        df.loc[(df['poll_result'] != 'not_recommended') & (df['recommended'] < df['best']), 'poll_result'] = 'best'
        df.loc[(df['poll_result'] != 'not_recommended') & (df['poll_result'] != 'best'), 'poll_result'] = 'recommended'
        return df
        
    def _get_best_player_counts(self, poll_result):
        best_player_counts = poll_result.loc[poll_result['poll_result'] == 'best', 'num_players'].tolist()
        return '|'.join(best_player_counts)
    
    def _get_recommended_player_counts(self, poll_result):
        recommended_player_counts = poll_result.loc[poll_result['poll_result'] != 'not_recommended', 'num_players'].tolist()
        return '|'.join(recommended_player_counts)
    

class CollectionXMLParser():
    def __init__(self, bgg_username):
        pass
    def get_users_collection(username):
        BASE_URI = 'https://www.boardgamegeek.com/xmlapi2/'
        collections_endpoint = BASE_URI + 'collection?'
        parameters = f'username={username}'
        return request,s.get(collections_endpoint + parameters)

# %%
collection = get_users_collection('bobbaganush')

# %%
# Uses the api, own cell not to re-send the request

collection_et = get_xml_string_from_response(collection)
game_ids = get_game_ids_from_collection(collection_et)

# %%
games = get_games_from_game_ids(game_ids)
games_et = get_xml_string_from_response(games)
# Out:
# https://www.boardgamegeek.com/xmlapi2/thing?id=68448,173346,31260,13464,205637,230802,170216,174506,174801,224517,171131,822,21385,13,926,325,553,478,178900,198773,39463,225694,104162,36218,5177,283355,157958,72125,246900,175621,177736,199478,169124,175155,37904,31481,23730,291457,193738,227460,198994,154597,859,154203,206051,84159,257501,257,70323,281960,823,143884,463,205059,1927,3943,1621,164928,30549,161936,221107,218603,2651,183006,28143,41114,181,121921,18,237182,438,169786,199727,242277,298638,8222,148228,187645,226840,1897,146508,189035,229853,120677,167791,247030,244522,182028,14996,276894,148951,233078,126163,122328,115746,228051,261594,262906,233867,266192,163602&stats=1

# %% [markdown]
# # sqlalchemy

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite:///db.sqlite', echo=True)

# %%
from sqlalchemy.ext.declarative import declarative_base

# %%
Base = declarative_base()

# %%
from sqlalchemy import Column, Integer, String

# %%
class User(Base):
    __tablename__ = 'users'
    id = Column(Integer, primary_key=True)
    name = Column(String, unique=True)

# %%
class UserGame(Base):
    __tablename__ = 'user_games'
    id = Column(Integer, primary_key=True)
    user_id = Column(Integer, nullable=False)
    bgg_game_id = Column(Integer, nullable=False)
    user_rating = Column(Integer)

# %%
class Game(Base):
    __tablename__ = 'games'
    id = Column(Integer, primary_key=True)
    bgg_game_id = Column(Integer, nullable=False, unique=True)
    title = Column(String, nullable=False)
    type = Column(String, nullable=False)
    year_published = Column(Integer, nullable=False)
    description = Column(String, nullable=False)
    image_url = Column(String, nullable=False)
    thumbnail_url = Column(String, nullable=False)
    min_players = Column(Integer, nullable=False)
    max_players = Column(Integer, nullable=False)
    playing_time = Column(Integer, nullable=False)
    min_playing_time = Column(Integer, nullable=False)
    max_playing_time = Column(Integer, nullable=False)
    min_age = Column(Integer, nullable=False)
    average_rating = Column(Integer, nullable=False)
    bayes_average_rating = Column(Integer, nullable=False)
    board_game_rank = Column(Integer, nullable=False)
    designers = Column(String, nullable=False)
    mechanics = Column(String, nullable=False)
    categories = Column(String, nullable=False)
    user_suggested_best_number_of_players = Column(String, nullable=False)
    user_suggested_recommended_number_of_players = Column(String, nullable=False)

# %%
Base.metadata.create_all(engine)
# Out:
# 2021-05-16 21:02:33,587 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2021-05-16 21:02:33,588 INFO sqlalchemy.engine.base.Engine ()
# 2021-05-16 21:02:33,592 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2021-05-16 21:02:33,593 INFO sqlalchemy.engine.base.Engine ()
# 2021-05-16 21:02:33,596 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("users")
# 2021-05-16 21:02:33,598 INFO sqlalchemy.engine.base.Engine ()
# 2021-05-16 21:02:33,601 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("users")
# 2021-05-16 21:02:33,603 INFO sqlalchemy.engine.base.Engine ()
# 2021-05-16 21:02:33,604 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("user_games")
# 2021-05-16 21:02:33,605 INFO sqlalchemy.engine.base.Engine ()
# 2021-05-16 21:02:33,607 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("user_games")
# 2021-05-16 21:02:33,608 INFO sqlalchemy.engine.base.Engine ()
# 2021-05-16 21:02:33,614 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("games")
# 2021-05-16 21:02:33,617 INFO sqlalchemy.engine.base.Engine ()
# 2021-05-16 21:02:33,619 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("games")
# 2021-05-16 21:02:33,620 INFO sqlalchemy.engine.base.Engine ()
# 2021-05-16 21:02:33,624 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE users (
# 	id INTEGER NOT NULL,
# 	name VARCHAR,
# 	PRIMARY KEY (id)
# )
#
#
# 2021-05-16 21:02:33,625 INFO sqlalchemy.engine.base.Engine ()
# 2021-05-16 21:02:33,648 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-05-16 21:02:33,654 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE user_games (
# 	id INTEGER NOT NULL,
# 	user_id INTEGER NOT NULL,
# 	bgg_game_id INTEGER NOT NULL,
# 	user_rating INTEGER,
# 	PRIMARY KEY (id)
# )
#
#
# 2021-05-16 21:02:33,657 INFO sqlalchemy.engine.base.Engine ()
# 2021-05-16 21:02:33,687 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-05-16 21:02:33,690 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE games (
# 	id INTEGER NOT NULL,
# 	bgg_game_id INTEGER NOT NULL,
# 	title VARCHAR NOT NULL,
# 	type VARCHAR NOT NULL,
# 	year_published INTEGER NOT NULL,
# 	description VARCHAR NOT NULL,
# 	image_url VARCHAR NOT NULL,
# 	thumbnail_url VARCHAR NOT NULL,
# 	min_players INTEGER NOT NULL,
# 	max_players INTEGER NOT NULL,
# 	playing_time INTEGER NOT NULL,
# 	min_playing_time INTEGER NOT NULL,
# 	max_playing_time INTEGER NOT NULL,
# 	min_age INTEGER NOT NULL,
# 	average_rating INTEGER NOT NULL,
# 	bayes_average_rating INTEGER NOT NULL,
# 	board_game_rank INTEGER NOT NULL,
# 	designers VARCHAR NOT NULL,
# 	mechanics VARCHAR NOT NULL,
# 	categories VARCHAR NOT NULL,
# 	user_suggested_best_number_of_players VARCHAR NOT NULL,
# 	user_suggested_recommended_number_of_players VARCHAR NOT NULL,
# 	PRIMARY KEY (id),
# 	UNIQUE (bgg_game_id)
# )
#
#
# 2021-05-16 21:02:33,694 INFO sqlalchemy.engine.base.Engine ()
# 2021-05-16 21:02:33,723 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
from sqlalchemy.orm import sessionmaker
Session = sessionmaker(bind=engine)

# %%
session = Session()

# %%
l = []
for game in games_et:
    bg = BoardgameXMLParser(game)
    bg_id_already_in_database = session.query(Game.bgg_game_id).filter(Game.bgg_game_id==bg.id).first() is not None
    if not bg_id_already_in_database:
        bg_sql = Game(
                     bgg_game_id=bg.id,
                     title=bg.title,
                     type=bg.type,
                     description=bg.description,
                     year_published=bg.year_published,
                     image_url=bg.image,
                     thumbnail_url=bg.thumbnail,
                     min_players=bg.min_players_from_creators,
                     max_players=bg.max_players_from_creators,
                     playing_time=bg.playing_time,
                     min_playing_time=bg.min_playing_time,
                     max_playing_time=bg.max_playing_time,
                     min_age=bg.min_age,
                     average_rating=bg.average_rating,
                     bayes_average_rating=bg.bayes_average_rating,
                     board_game_rank=bg.board_game_rank,
                     designers=bg.designers,
                     mechanics=bg.mechanics,
                     categories=bg.categories,
                     user_suggested_best_number_of_players=bg.user_suggested_best_number_of_players,
                     user_suggested_recommended_number_of_players=bg.user_suggested_recommended_number_of_players
                     )
        l.append(bg_sql)
    else:
        print('game already in games.')
session.add_all(l)
    
session.commit()
# Out:
# 2021-05-16 22:02:54,973 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2021-05-16 22:02:54,976 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:54,977 INFO sqlalchemy.engine.base.Engine ('68448', 1, 0)
# game already in games.
# 2021-05-16 22:02:54,988 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:54,990 INFO sqlalchemy.engine.base.Engine ('173346', 1, 0)
# game already in games.
# 2021-05-16 22:02:55,006 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:55,007 INFO sqlalchemy.engine.base.Engine ('31260', 1, 0)
# game already in games.
# 2021-05-16 22:02:55,021 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:55,024 INFO sqlalchemy.engine.base.Engine ('13464', 1, 0)
# game already in games.
# 2021-05-16 22:02:55,059 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:55,061 INFO sqlalchemy.engine.base.Engine ('205637', 1, 0)
# game already in games.
# 2021-05-16 22:02:55,089 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:55,091 INFO sqlalchemy.engine.base.Engine ('230802', 1, 0)
# game already in games.
# 2021-05-16 22:02:55,106 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:55,108 INFO sqlalchemy.engine.base.Engine ('170216', 1, 0)
# game already in games.
# 2021-05-16 22:02:55,125 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:55,129 INFO sqlalchemy.engine.base.Engine ('174506', 1, 0)
# game already in games.
# 2021-05-16 22:02:55,167 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:55,178 INFO sqlalchemy.engine.base.Engine ('174801', 1, 0)
# game already in games.
# 2021-05-16 22:02:55,197 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:55,199 INFO sqlalchemy.engine.base.Engine ('224517', 1, 0)
# game already in games.
# 2021-05-16 22:02:55,220 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:55,228 INFO sqlalchemy.engine.base.Engine ('171131', 1, 0)
# game already in games.
# 2021-05-16 22:02:55,252 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:55,255 INFO sqlalchemy.engine.base.Engine ('822', 1, 0)
# game already in games.
# 2021-05-16 22:02:55,289 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:55,293 INFO sqlalchemy.engine.base.Engine ('21385', 1, 0)
# game already in games.
# 2021-05-16 22:02:55,323 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:55,325 INFO sqlalchemy.engine.base.Engine ('13', 1, 0)
# game already in games.
# 2021-05-16 22:02:55,353 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:55,355 INFO sqlalchemy.engine.base.Engine ('926', 1, 0)
# game already in games.
# 2021-05-16 22:02:55,364 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:55,365 INFO sqlalchemy.engine.base.Engine ('325', 1, 0)
# game already in games.
# 2021-05-16 22:02:55,379 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:55,395 INFO sqlalchemy.engine.base.Engine ('553', 1, 0)
# game already in games.
# 2021-05-16 22:02:55,426 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:55,430 INFO sqlalchemy.engine.base.Engine ('478', 1, 0)
# game already in games.
# 2021-05-16 22:02:55,457 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:55,461 INFO sqlalchemy.engine.base.Engine ('178900', 1, 0)
# game already in games.
# 2021-05-16 22:02:55,483 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:55,486 INFO sqlalchemy.engine.base.Engine ('198773', 1, 0)
# game already in games.
# 2021-05-16 22:02:55,503 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:55,509 INFO sqlalchemy.engine.base.Engine ('39463', 1, 0)
# game already in games.
# 2021-05-16 22:02:55,540 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:55,541 INFO sqlalchemy.engine.base.Engine ('225694', 1, 0)
# game already in games.
# 2021-05-16 22:02:55,558 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:55,560 INFO sqlalchemy.engine.base.Engine ('104162', 1, 0)
# game already in games.
# 2021-05-16 22:02:55,574 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:55,575 INFO sqlalchemy.engine.base.Engine ('36218', 1, 0)
# game already in games.
# 2021-05-16 22:02:55,603 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:55,604 INFO sqlalchemy.engine.base.Engine ('5177', 1, 0)
# game already in games.
# 2021-05-16 22:02:55,625 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:55,626 INFO sqlalchemy.engine.base.Engine ('283355', 1, 0)
# game already in games.
# 2021-05-16 22:02:55,637 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:55,638 INFO sqlalchemy.engine.base.Engine ('157958', 1, 0)
# game already in games.
# 2021-05-16 22:02:55,651 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:55,652 INFO sqlalchemy.engine.base.Engine ('72125', 1, 0)
# game already in games.
# 2021-05-16 22:02:55,679 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:55,682 INFO sqlalchemy.engine.base.Engine ('246900', 1, 0)
# game already in games.
# 2021-05-16 22:02:55,714 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:55,716 INFO sqlalchemy.engine.base.Engine ('175621', 1, 0)
# game already in games.
# 2021-05-16 22:02:55,739 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:55,742 INFO sqlalchemy.engine.base.Engine ('177736', 1, 0)
# game already in games.
# 2021-05-16 22:02:55,760 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:55,761 INFO sqlalchemy.engine.base.Engine ('199478', 1, 0)
# game already in games.
# 2021-05-16 22:02:55,778 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:55,781 INFO sqlalchemy.engine.base.Engine ('169124', 1, 0)
# game already in games.
# 2021-05-16 22:02:55,813 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:55,815 INFO sqlalchemy.engine.base.Engine ('175155', 1, 0)
# game already in games.
# 2021-05-16 22:02:55,828 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:55,829 INFO sqlalchemy.engine.base.Engine ('37904', 1, 0)
# game already in games.
# 2021-05-16 22:02:55,847 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:55,848 INFO sqlalchemy.engine.base.Engine ('31481', 1, 0)
# game already in games.
# 2021-05-16 22:02:55,861 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:55,863 INFO sqlalchemy.engine.base.Engine ('23730', 1, 0)
# game already in games.
# 2021-05-16 22:02:55,880 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:55,881 INFO sqlalchemy.engine.base.Engine ('291457', 1, 0)
# game already in games.
# 2021-05-16 22:02:55,895 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:55,902 INFO sqlalchemy.engine.base.Engine ('193738', 1, 0)
# game already in games.
# 2021-05-16 22:02:55,920 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:55,922 INFO sqlalchemy.engine.base.Engine ('227460', 1, 0)
# game already in games.
# 2021-05-16 22:02:55,938 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:55,943 INFO sqlalchemy.engine.base.Engine ('198994', 1, 0)
# game already in games.
# 2021-05-16 22:02:55,957 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:55,958 INFO sqlalchemy.engine.base.Engine ('154597', 1, 0)
# game already in games.
# 2021-05-16 22:02:55,973 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:55,975 INFO sqlalchemy.engine.base.Engine ('859', 1, 0)
# game already in games.
# 2021-05-16 22:02:56,004 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:56,005 INFO sqlalchemy.engine.base.Engine ('154203', 1, 0)
# game already in games.
# 2021-05-16 22:02:56,025 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:56,026 INFO sqlalchemy.engine.base.Engine ('206051', 1, 0)
# game already in games.
# 2021-05-16 22:02:56,040 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:56,042 INFO sqlalchemy.engine.base.Engine ('84159', 1, 0)
# game already in games.
# 2021-05-16 22:02:56,075 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:56,078 INFO sqlalchemy.engine.base.Engine ('257501', 1, 0)
# game already in games.
# 2021-05-16 22:02:56,095 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:56,096 INFO sqlalchemy.engine.base.Engine ('257', 1, 0)
# game already in games.
# 2021-05-16 22:02:56,140 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:56,143 INFO sqlalchemy.engine.base.Engine ('70323', 1, 0)
# game already in games.
# 2021-05-16 22:02:56,160 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:56,161 INFO sqlalchemy.engine.base.Engine ('281960', 1, 0)
# game already in games.
# 2021-05-16 22:02:56,179 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:56,181 INFO sqlalchemy.engine.base.Engine ('823', 1, 0)
# game already in games.
# 2021-05-16 22:02:56,201 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:56,203 INFO sqlalchemy.engine.base.Engine ('143884', 1, 0)
# game already in games.
# 2021-05-16 22:02:56,235 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:56,240 INFO sqlalchemy.engine.base.Engine ('463', 1, 0)
# game already in games.
# 2021-05-16 22:02:56,259 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:56,260 INFO sqlalchemy.engine.base.Engine ('205059', 1, 0)
# game already in games.
# 2021-05-16 22:02:56,283 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:56,284 INFO sqlalchemy.engine.base.Engine ('1927', 1, 0)
# game already in games.
# 2021-05-16 22:02:56,312 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:56,313 INFO sqlalchemy.engine.base.Engine ('3943', 1, 0)
# game already in games.
# 2021-05-16 22:02:56,332 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:56,335 INFO sqlalchemy.engine.base.Engine ('1621', 1, 0)
# game already in games.
# 2021-05-16 22:02:56,352 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:56,353 INFO sqlalchemy.engine.base.Engine ('164928', 1, 0)
# game already in games.
# 2021-05-16 22:02:56,375 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:56,376 INFO sqlalchemy.engine.base.Engine ('30549', 1, 0)
# game already in games.
# 2021-05-16 22:02:56,388 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:56,393 INFO sqlalchemy.engine.base.Engine ('161936', 1, 0)
# game already in games.
# 2021-05-16 22:02:56,419 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:56,420 INFO sqlalchemy.engine.base.Engine ('221107', 1, 0)
# game already in games.
# 2021-05-16 22:02:56,444 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:56,446 INFO sqlalchemy.engine.base.Engine ('218603', 1, 0)
# game already in games.
# 2021-05-16 22:02:56,465 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:56,467 INFO sqlalchemy.engine.base.Engine ('2651', 1, 0)
# game already in games.
# 2021-05-16 22:02:56,492 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:56,494 INFO sqlalchemy.engine.base.Engine ('183006', 1, 0)
# game already in games.
# 2021-05-16 22:02:56,520 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:56,521 INFO sqlalchemy.engine.base.Engine ('28143', 1, 0)
# game already in games.
# 2021-05-16 22:02:56,532 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:56,534 INFO sqlalchemy.engine.base.Engine ('41114', 1, 0)
# game already in games.
# 2021-05-16 22:02:56,552 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:56,556 INFO sqlalchemy.engine.base.Engine ('181', 1, 0)
# game already in games.
# 2021-05-16 22:02:56,572 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:56,574 INFO sqlalchemy.engine.base.Engine ('121921', 1, 0)
# game already in games.
# 2021-05-16 22:02:56,597 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:56,598 INFO sqlalchemy.engine.base.Engine ('18', 1, 0)
# game already in games.
# 2021-05-16 22:02:56,611 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:56,612 INFO sqlalchemy.engine.base.Engine ('237182', 1, 0)
# game already in games.
# 2021-05-16 22:02:56,630 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:56,633 INFO sqlalchemy.engine.base.Engine ('438', 1, 0)
# game already in games.
# 2021-05-16 22:02:56,651 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:56,652 INFO sqlalchemy.engine.base.Engine ('169786', 1, 0)
# game already in games.
# 2021-05-16 22:02:56,675 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:56,676 INFO sqlalchemy.engine.base.Engine ('199727', 1, 0)
# game already in games.
# 2021-05-16 22:02:56,687 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:56,688 INFO sqlalchemy.engine.base.Engine ('242277', 1, 0)
# game already in games.
# 2021-05-16 22:02:56,701 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:56,706 INFO sqlalchemy.engine.base.Engine ('298638', 1, 0)
# game already in games.
# 2021-05-16 22:02:56,725 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:56,726 INFO sqlalchemy.engine.base.Engine ('8222', 1, 0)
# game already in games.
# 2021-05-16 22:02:56,751 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:56,753 INFO sqlalchemy.engine.base.Engine ('148228', 1, 0)
# game already in games.
# 2021-05-16 22:02:56,765 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:56,766 INFO sqlalchemy.engine.base.Engine ('187645', 1, 0)
# game already in games.
# 2021-05-16 22:02:56,795 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:56,799 INFO sqlalchemy.engine.base.Engine ('226840', 1, 0)
# game already in games.
# 2021-05-16 22:02:56,828 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:56,829 INFO sqlalchemy.engine.base.Engine ('1897', 1, 0)
# game already in games.
# 2021-05-16 22:02:56,842 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:56,843 INFO sqlalchemy.engine.base.Engine ('146508', 1, 0)
# game already in games.
# 2021-05-16 22:02:56,863 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:56,869 INFO sqlalchemy.engine.base.Engine ('189035', 1, 0)
# game already in games.
# 2021-05-16 22:02:56,896 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:56,897 INFO sqlalchemy.engine.base.Engine ('229853', 1, 0)
# game already in games.
# 2021-05-16 22:02:56,908 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:56,909 INFO sqlalchemy.engine.base.Engine ('120677', 1, 0)
# game already in games.
# 2021-05-16 22:02:56,921 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:56,922 INFO sqlalchemy.engine.base.Engine ('167791', 1, 0)
# game already in games.
# 2021-05-16 22:02:56,938 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:56,939 INFO sqlalchemy.engine.base.Engine ('247030', 1, 0)
# game already in games.
# 2021-05-16 22:02:56,970 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:56,973 INFO sqlalchemy.engine.base.Engine ('244522', 1, 0)
# game already in games.
# 2021-05-16 22:02:56,985 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:56,990 INFO sqlalchemy.engine.base.Engine ('182028', 1, 0)
# game already in games.
# 2021-05-16 22:02:57,006 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:57,013 INFO sqlalchemy.engine.base.Engine ('14996', 1, 0)
# game already in games.
# 2021-05-16 22:02:57,023 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:57,024 INFO sqlalchemy.engine.base.Engine ('276894', 1, 0)
# game already in games.
# 2021-05-16 22:02:57,033 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:57,034 INFO sqlalchemy.engine.base.Engine ('148951', 1, 0)
# game already in games.
# 2021-05-16 22:02:57,051 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:57,052 INFO sqlalchemy.engine.base.Engine ('233078', 1, 0)
# game already in games.
# 2021-05-16 22:02:57,076 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:57,077 INFO sqlalchemy.engine.base.Engine ('126163', 1, 0)
# game already in games.
# 2021-05-16 22:02:57,090 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:57,091 INFO sqlalchemy.engine.base.Engine ('122328', 1, 0)
# game already in games.
# 2021-05-16 22:02:57,110 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:57,111 INFO sqlalchemy.engine.base.Engine ('115746', 1, 0)
# game already in games.
# 2021-05-16 22:02:57,122 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:57,123 INFO sqlalchemy.engine.base.Engine ('228051', 1, 0)
# game already in games.
# 2021-05-16 22:02:57,148 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:57,149 INFO sqlalchemy.engine.base.Engine ('261594', 1, 0)
# game already in games.
# 2021-05-16 22:02:57,151 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:57,153 INFO sqlalchemy.engine.base.Engine ('262906', 1, 0)
# game already in games.
# 2021-05-16 22:02:57,165 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:57,166 INFO sqlalchemy.engine.base.Engine ('233867', 1, 0)
# game already in games.
# 2021-05-16 22:02:57,180 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:57,181 INFO sqlalchemy.engine.base.Engine ('266192', 1, 0)
# game already in games.
# 2021-05-16 22:02:57,201 INFO sqlalchemy.engine.base.Engine SELECT games.bgg_game_id AS games_bgg_game_id
# FROM games
# WHERE games.bgg_game_id = ?
#  LIMIT ? OFFSET ?
# 2021-05-16 22:02:57,207 INFO sqlalchemy.engine.base.Engine ('163602', 1, 0)
# game already in games.
# 2021-05-16 22:02:57,209 INFO sqlalchemy.engine.base.Engine COMMIT
